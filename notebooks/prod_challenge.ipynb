# %%
import rootutils

root_dir = rootutils.setup_root(".",
                                indicator=".project-root",
                                pythonpath=True)

# %%
from src.main import main
from src.cache import clear_entire_cache, clear_cache_for_molecule
import json
# Out:
# /Users/shreyasv/miniforge3/envs/retrollm/lib/python3.10/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
mol_target = "ClC(C(OC)=C1)=CC2=C1[C@@H]3[C@@H](N(C)CC2)CCC4=CC=CC=C43"

# %%
# clear_cache_for_molecule(mol_target)

# %%
# challenge mols

mols_small = {
    "Favipiravir": "NC(=O)C1=NC(F)=CN=C1O",
    # "Chlorzoxazone": "ClC1=CC2=C(OC(=O)N2)C=C1",
    # "Metronidazole": "CC1=NC=C(N1CCO)[N+]([O-])=O",
    # "Theophylline": "CN1C2=C(NC=N2)C(=O)N(C)C1=O",
    # "Propylparaben": "CCCOC(=O)C1=CC=C(O)C=C1",
    # "Secnidazole": "CC(O)CN1C(C)=NC=C1N(=O)=O",
    "Tocainide": "CC(N)C(=O)NC1=C(C)C=CC=C1C",
    # "Enprofylline": "CCCN1C2=C(NC=N2)C(=O)NC1=O",
    # "Milrinone": "CC1=C(C=C(C#N)C(=O)N1)C1=CC=NC=C1",
    # "Methyldopa": "C[C@](N)(CC1=CC=C(O)C(O)=C1)C(O)=O",
    "Methoxamine": "COC1=CC(C(O)C(C)N)=C(OC)C=C1",
    # "Zonisamide": "NS(=O)(=O)CC1=NOC2=CC=CC=C12",
    # "Flavone": "O=C1C=C(OC2=CC=CC=C12)C1=CC=CC=C1",
    # "Diazoxide": "CC1=NS(=O)(=O)C2=C(N1)C=CC(Cl)=C2",
    # "Naproxen": "COC1=CC2=C(C=C1)C=C(C=C2)[C@H](C)C(O)=O",
    # "Nalidixic acid": "CCN1C=C(C(O)=O)C(=O)C2=C1N=C(C)C=C2",
    # "Phenobarbital": "CCC1(C(=O)NC(=O)NC1=O)C1=CC=CC=C1",
    # "Melatonin": "COC1=CC2=C(NC=C2CCNC(C)=O)C=C1",
    # "Sulbactam": "[H][C@@]12CC(=O)N1[C@@]([H])(C(O)=O)C(C)(C)S2(=O)=O",
    # "Riluzole": "NC1=NC2=C(S1)C=C(OC(F)(F)F)C=C2",
    # "Didanosine": "OC[C@@H]1CC[C@@H](O1)N1C=NC2=C1NC=NC2=O",
    # "Tilbroquinol": "CC1=C2C=CC=NC2=C(O)C(Br)=C1",
    # "Sulfadiazine": "NC1=CC=C(C=C1)S(=O)(=O)NC1=NC=CC=N1",
    # "Phenprocoumon": "CCC(C1=CC=CC=C1)C1=C(O)C2=C(OC1=O)C=CC=C2",
}

mols = {
    "plazomicin":
    "C[C@@]1(CO[C@@H]([C@@H]([C@H]1NC)O)O[C@H]2[C@@H](C[C@@H]([C@H]([C@@H]2O)O[C@@H]3[C@@H](CC=C(O3)CNCCO)N)N)NC(=O)[C@H](CCN)O)O",
    "quinine": "COC1=CC2=C(C=CN=C2C=C1)[C@H]([C@@H]3C[C@@H]4CCN3C[C@@H]4C=C)O",
    "artemisinin":
    "C[C@@H]1CC[C@H]2[C@H](C(=O)O[C@H]3[C@@]24[C@H]1CC[C@](O3)(OO4)C)C",
    "penicillin":
    "CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C",
}

mols_hard = {
    # "maitotoxin":
    # "C[C@H](CC[C@@H]([C@@H]([C@H](C)C[C@H](C(=C)/C(=C/CO)/C)O)O)OS(=O)(=O)[O-])[C@H]([C@@H](C)[C@H]1[C@@H]([C@@H]([C@H]2[C@H](O1)[C@@H](C[C@]3([C@H](O2)C[C@H]4[C@H](O3)C[C@]5([C@H](O4)[C@H]([C@H]6[C@H](O5)C[C@H]([C@H](O6)[C@@H]([C@H](C[C@H]7[C@@H]([C@@H]([C@H]8[C@H](O7)C[C@H]9[C@H](O8)C[C@H]1[C@H](O9)[C@H]([C@@H]2[C@@H](O1)[C@@H]([C@H]([C@@H](O2)[C@H]1[C@@H]([C@H]([C@H]2[C@@H](O1)C[C@H]([C@@H](O2)[C@@H](C[C@H](C[C@H]1[C@@H]([C@H]([C@H]2[C@@H](O1)C[C@H]([C@@H](O2)[C@H]1[C@@H](C[C@]2([C@H](O1)[C@@H]([C@]1([C@H](O2)C[C@]2([C@H](O1)CC[C@]1([C@H](O2)C[C@]2([C@H](O1)C[C@H]1[C@H](O2)CC[C@H](O1)[C@]1([C@@H](C[C@H]2[C@](O1)(C[C@H]1[C@](O2)(CC[C@]2([C@H](O1)C[C@H]1[C@](O2)(C[C@H]2[C@H](O1)C/C=C\[C@H]1[C@H](O2)C[C@H]2[C@](O1)(C[C@]1([C@H](O2)C[C@H]2[C@](O1)(CC[C@H](O2)[C@H]([C@@H](C[C@@H](C)[C@@H](C)CC=C)O)O)C)C)C)C)C)C)C)O)C)C)C)C)C)O)C)O)O)O)O)O)O)O)O)O)O)O)O)O)OS(=O)(=O)[O-])O)O)O)O)C)C)O)O)O)O",
    # "taxol":
    # "CC1=C2[C@H](C(=O)[C@@]3([C@H](C[C@@H]4[C@](C3[C@@H]([C@@](C2(C)C)(C[C@@H]1OC(=O)[C@@H]([C@H](C5=CC=CC=C5)NC(=O)C6=CC=CC=C6)O)O)OC(=O)C7=CC=CC=C7)(CO4)OC(=O)C)O)C)OC(=O)C",
    "dalbavancin":
    "CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O",
    # "palytoxin":
    # "C[C@H]1C[C@@]2([C@H](O[C@](C1)(O2)CCCCCCC[C@@H](C[C@@H]3[C@@H]([C@H]([C@H]([C@@](O3)(C[C@@H]([C@@H](C)/C=C/[C@H](CC[C@H]([C@H]([C@@H]4C[C@H]([C@@H]([C@H](O4)C[C@H]([C@@H](C[C@@H]5[C@H]([C@@H]([C@H]([C@@H](O5)C[C@@H](/C=C\C=C\C[C@H]([C@@H]([C@@H](C/C=C\C(=C)CC[C@@H]([C@H]([C@@H]([C@H](C)C[C@@H]6[C@@H]([C@H]([C@@H]([C@H](O6)/C=C\[C@H]([C@@H](C[C@@H]7C[C@@H]8C[C@H](O7)[C@H](O8)CC[C@@H]9[C@@H](C[C@H](O9)CN)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)O)C[C@@H](C)CCCCC[C@H]([C@@H]([C@@H]([C@H]([C@@H]([C@@H]1[C@H]([C@@H]([C@H]([C@H](O1)C[C@@H]([C@@H](/C(=C/[C@@H](C[C@@H](C)[C@@H](C(=O)N/C=C/C(=O)NCCCO)O)O)/C)O)O)O)O)O)O)O)O)O)O)C",
    # "Sirolimus":
    # "C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C/[C@H](C[C@H](C(=O)[C@@H]([C@@H](/C(=C/[C@H](C(=O)C[C@H](OC(=O)[C@@H]3CCCCN3C(=O)C(=O)[C@@]1(O2)O)[C@H](C)C[C@@H]4CC[C@H]([C@@H](C4)OC)O)C)/C)O)OC)C)C)/C)OC",
    # "cyclosporin a":
    # "CC[C@H]1C(=O)N(CC(=O)N([C@H](C(=O)N[C@H](C(=O)N([C@H](C(=O)N[C@H](C(=O)N[C@@H](C(=O)N([C@H](C(=O)N([C@H](C(=O)N([C@H](C(=O)N([C@H](C(=O)N1)[C@@H]([C@H](C)C/C=C/C)O)C)C(C)C)C)CC(C)C)C)CC(C)C)C)C)C)CC(C)C)C)C(C)C)CC(C)C)C)C",
    # "rapamycin":
    # "C[C@@H]1CCC2C[C@@H](/C(=C/C=C/C=C/[C@H](C[C@H](C(=O)[C@@H]([C@@H](/C(=C/[C@H](C(=O)C[C@H](OC(=O)[C@@H]3CCCCN3C(=O)C(=O)[C@@]1(O2)O)[C@H](C)C[C@@H]4CC[C@H]([C@@H](C4)OC)O)C)/C)O)OC)C)C)/C)OC",
}

# %%
# clear_entire_cache()

# %%
# # make a list of all molecules that are complete

# dir_results = "results/"

# # find folders in dir_results
# import os

# folders = [
#     f for f in os.listdir(dir_results)
#     if os.path.isdir(os.path.join(dir_results, f))
# ]

# # find all molecules that are complete
# molecules = {}
# for folder in folders:
#     with open(os.path.join(dir_results, folder, "results.json")) as f:
#         results = json.load(f)
#         for mol, result in results.items():
#             if result["status"] == "complete":
#                 molecules[mol] = result

# %%
# print(f"Running {mol_target}")
# try:
#     res_dict = main(mol_target)  #, llm="o1-preview-2024-09-12")
#     with open(f"{root_dir}/results/mols_small/{mol_target}_claude_cot.json",
#               "w") as f:
#         json.dump(res_dict, f, indent=4)
# except Exception as e:
#     print("Error in molecule:", mol_target)
#     print("Error:", e)

# %%
for mol in mols_small:
    molecule = mols_small[mol]
    print(f"Running {mol}")
    try:
        clear_cache_for_molecule(molecule)
        res_dict = main(molecule)  #, llm="o1-preview-2024-09-12")
        with open(f"{root_dir}/results/mols_small/{mol}_claude_new.json",
                  "w") as f:
            json.dump(res_dict, f, indent=4)
    except Exception as e:
        print("Error in molecule:", mol)
        print("Error:", e)
# Out:
# 2025-02-14 18:54:17 [info     ] -------------------------------------------------- filename=main.py lineno=29
# 2025-02-14 18:54:17 [info     ] Application initialization complete filename=main.py lineno=30
# 2025-02-14 18:54:17 [info     ] Starting new synthesis job 20250215_002417_96180 for molecule NC(=O)C1=NC(F)=CN=C1O filename=prithvi.py job_id=20250215_002417_96180 lineno=31
# 2025-02-14 18:54:17 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Running Favipiravir
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 18:56:00 [info     ] AZ failed for NC(=O)C1=NC(F)=CN=C1O, running LLM filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=31
# Calling LLM with molecule: NC(=O)C1=NC(F)=CN=C1O and run: 0.0
# Calling claude-3-opus-20240229 with molecule: NC(=O)C1=NC(F)=CN=C1O
# 00:26:01 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:27:06 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:27:06 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 2025-02-14 18:57:06 [info     ] LLM returned [['OC1=NC=C(F)C(C(N)=O)=N1', 'NCC(=O)C1=CC(F)=NC(O)=N1']] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=53
# 2025-02-14 18:57:06 [info     ] LLM explained ['Pyridine ring formation: Condense a β-ketoester with 2-fluoroacetonitrile and hydroxylamine to form an oxime, then cyclize to the substituted pyridine.'] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=54
# 2025-02-14 18:57:06 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Received response from LLM: Here is my retrosynthetic analysis for the target molecule with SMILES string NC(=O)C1=NC(F)=CN=C1O:
#
# <cot>
# <thinking type="initial_assessment">
# Initial structural analysis:
# - The molecule has a pyridine core with three substituents:
#    * Fluorine at the 4-position
#    * Hydroxyl group at the 6-position
#    * Carboxamide at the 2-position
# - The pyridine ring and carboxamide are coplanar, allowing conjugation
# - The fluorine and hydroxyl groups are oriented to minimize steric interactions
# - No stereogenic centers are present
#
# After reflection:
# - The analysis correctly identifies all key structural features
# - The planar, conjugated structure is properly recognized
# - No hidden symmetry elements or strained geometries are apparent
# </thinking>
#
# <thinking type="strategic_analysis">
# Potential disconnection strategies:
# 1. Amide formation
#    - Disconnect the carboxamide C-N bond
#    - Requires 4-fluoro-6-hydroxypicolinic acid and ammonia
#    - Precedented amide coupling methods available
#
# 2. Pyridine ring formation
#    - Disconnect the pyridine N-C2 and C5-C6 bonds
#    - Requires a β-ketoester, 2-fluoroacetonitrile, and hydroxylamine
#    - Condensation forms oxime, then cyclizes to pyridine
#
# 3. C-F bond formation
#    - Disconnect the C-F bond
#    - Requires 6-hydroxypicolinamide and an electrophilic fluorine source
#    - Selective fluorination at the 4-position may be challenging
#
# 4. C-OH bond formation
#    - Disconnect the C-OH bond
#    - Requires 4-fluoropicolinamide and an oxidant
#    - Selective hydroxylation at the 6-position may be difficult
#
# After evaluation:
# - The amide formation approach is most straightforward and precedented
# - Pyridine ring formation is elegant but requires more steps and unique components
# - Selective fluorination and hydroxylation are likely to be low-yielding
# </thinking>
#
# <thinking type="practical_considerations">
# Practical assessment of favored approaches:
# 1. Amide formation
#    - 4-Fluoro-6-hydroxypicolinic acid is commercially available on gram scale
#    - Many reliable amide coupling reagents exist (e.g. HATU, PyBOP)
#    - Reaction likely performs well in common solvents (DMF, DCM)
#    - Aqueous workup and crystallization may be sufficient for purification
#
# 2. Pyridine ring formation
#    - The β-ketoester is available in bulk but may require distillation
#    - 2-Fluoroacetonitrile is a specialty chemical with limited availability
#    - Hydroxylamine is common but has safety concerns (explosion potential)
#    - Likely requires chromatography to separate regioisomers
#
# After practical review:
# - Amide formation has a clear advantage in starting material availability
# - Ring formation uses more exotic reagents and has purification challenges
# - Safety considerations further favor the amide formation approach
# </thinking>
#
# <thinking type="final_selection">
# Final proposal ranking and rationale:
# 1. Amide formation (confidence score: 0.85)
#    - Utilizes easily obtained starting materials
#    - Relies on well-precedented chemistry
#    - Offers simple purification options
#    - Minimal safety concerns
#
# 2. Pyridine ring formation (confidence score: 0.60)
#    - Provides an elegant and convergent approach
#    - Requires harder to source chemicals
#    - Introduces purification challenges
#    - Has some safety concerns around hydroxylamine
#
# After final validation:
# - The amide formation proposal balances innovation and pragmatism
# - It is supported by literature precedent and is well-suited for scale-up
# - The confidence scores realistically reflect the strategic advantages and practical considerations
# </thinking>
# </cot>
#
# <json>
# {
#   "thinking_process": [
#     {
#       "stage": "initial_assessment",
#       "analysis": "The molecule has a pyridine core with three substituents: fluorine at the 4-position, a hydroxyl group at the 6-position, and a carboxamide at the 2-position. The pyridine ring and carboxamide are coplanar, allowing conjugation. The fluorine and hydroxyl groups are oriented to minimize steric interactions. No stereogenic centers are present.",
#       "reflection": "The analysis correctly identifies all key structural features. The planar, conjugated structure is properly recognized. No hidden symmetry elements or strained geometries are apparent."
#     },
#     {
#       "stage": "strategic_analysis",
#       "analysis": "Four potential disconnection strategies were considered: (1) amide formation, (2) pyridine ring formation, (3) C-F bond formation, and (4) C-OH bond formation. The amide formation approach disconnects the carboxamide C-N bond and requires 4-fluoro-6-hydroxypicolinic acid and ammonia. The pyridine ring formation disconnects the N-C2 and C5-C6 bonds, requiring a β-ketoester, 2-fluoroacetonitrile, and hydroxylamine. C-F and C-OH bond formations have selectivity challenges.",
#       "reflection": "The amide formation approach is most straightforward and precedented. Pyridine ring formation is elegant but requires more steps and unique components. Selective fluorination and hydroxylation are likely to be low-yielding."
#     },
#     {
#       "stage": "practical_considerations",
#       "analysis": "For amide formation, 4-fluoro-6-hydroxypicolinic acid is commercially available and the reaction can use standard coupling reagents and solvents. Aqueous workup and crystallization may suffice for purification. For pyridine ring formation, the β-ketoester is available in bulk, but 2-fluoroacetonitrile has limited availability. Hydroxylamine has safety concerns. Chromatography would likely be needed to separate regioisomers.",
#       "reflection": "Amide formation has a clear advantage in starting material availability. Ring formation uses more exotic reagents and has purification challenges. Safety considerations further favor the amide formation approach."
#     },
#     {
#       "stage": "final_selection",
#       "analysis": "The two most promising approaches were ranked: (1) amide formation with a confidence score of 0.85, and (2) pyridine ring formation with a score of 0.60. The amide route uses easily obtained starting materials, relies on precedented chemistry, enables simple purification, and has minimal safety concerns. The ring formation is elegant and convergent but requires harder to source chemicals, introduces purification challenges, and has some safety issues.",
#       "reflection": "The amide formation proposal balances innovation and pragmatism. It is supported by literature precedent and is well-suited for scale-up. The confidence scores realistically reflect the strategic advantages and practical considerations."
#     }
#   ],
#   "data": [
#     ["NC(=O)c1cc(F)c(O)nc1"],
#     ["OC1=NC=C(F)C(C(N)=O)=N1", "NCC(=O)C1=CC(F)=NC(O)=N1"]
#   ],
#   "explanation": [
#     "Amide formation: Couple 4-fluoro-6-hydroxypicolinic acid with ammonia using a standard peptide coupling reagent (e.g. HATU, PyBOP).",
#     "Pyridine ring formation: Condense a β-ketoester with 2-fluoroacetonitrile and hydroxylamine to form an oxime, then cyclize to the substituted pyridine."
#   ],
#   "confidence_scores": [
#     0.85,
#     0.60
#   ]
# }
# </json>
# Obtained 1 valid pathways after validity test: [['OC1=NC=C(F)C(C(N)=O)=N1', 'NCC(=O)C1=CC(F)=NC(O)=N1']]
# Output Pathways: [['OC1=NC=C(F)C(C(N)=O)=N1', 'NCC(=O)C1=CC(F)=NC(O)=N1']],
#                 Output Explanations: ['Pyridine ring formation: Condense a β-ketoester with 2-fluoroacetonitrile and hydroxylamine to form an oxime, then cyclize to the substituted pyridine.'],
#                     Output Confidence: [0.6]
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 18:59:12 [info     ] AZ failed for OC1=NC=C(F)C(C(N)=O)=N1, running LLM filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=31
# 00:29:12 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# Calling LLM with molecule: OC1=NC=C(F)C(C(N)=O)=N1 and run: 0.0
# Calling claude-3-opus-20240229 with molecule: OC1=NC=C(F)C(C(N)=O)=N1
# 00:30:17 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:30:17 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 2025-02-14 19:00:17 [info     ] LLM returned [['NC1=NC(O)=NC(F)=C1', 'C(=O)C(=O)CC(=O)C(N)=O'], ['NC1=CC(F)=NC(O)=N1', 'Cl']] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=53
# 2025-02-14 19:00:17 [info     ] LLM explained ['Cyclocondensation of 2-amino-6-fluoro-4-hydroxypyrimidine and a 1,3-dicarbonyl compound', 'N1-C2 bond formation via amination of 2-amino-6-fluoropyrimidin-4-ol with ammonia source'] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=54
# 2025-02-14 19:00:17 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Received response from LLM: Here is my retrosynthetic analysis for the target molecule with SMILES string OC1=NC=C(F)C(C(N)=O)=N1:
#
# <cot>
# <thinking type="initial_assessment">
# Initial structural analysis:
# - The molecule is a monocyclic aromatic heterocycle
# - It contains a fused 6,6 ring system with 3 nitrogen atoms
# - The ring contains an amide functional group and a fluorine substituent
# - There are no stereogenic centers present
# - The molecule appears to be a fluorinated pyrimidine derivative
#
# After further consideration:
# - The structure is unambiguous and the SMILES is valid
# - The complexity is appropriate for single-step retrosynthetic analysis
# - No hidden symmetry or unusual strain elements are apparent
# </thinking>
#
# <thinking type="strategic_analysis">
# Potential disconnection strategies:
# 1. Amide formation
#    - Disconnect the amide C-N bond
#    - Requires a carboxylic acid and an amine
#    - Likely requires activating agents (e.g. coupling reagents)
#
# 2. Nucleophilic aromatic substitution
#    - Disconnect the C-F bond
#    - Requires a nucleophilic fluorine source
#    - May be challenging due to low reactivity of fluoride
#
# 3. Pyrimidine ring formation
#    - Deconstruct the pyrimidine core
#    - Could involve cyclocondensation of amidine and 1,3-dicarbonyl
#    - Allows potential late-stage fluorination
#
# 4. C-N bond formation
#    - Break N1-C2 bond to give 2-amino heterocycle
#    - Requires selective amination method
#    - Enables modular building block approach
#
# After evaluating strategies:
# - The amide formation seems most straightforward
# - Pyrimidine synthesis is appealing but less convergent
# - SNAr approach limited by fluoride reactivity
# - C-N bond formation is novel but untested
# </thinking>
#
# <thinking type="practical_considerations">
# Practical aspects of proposed routes:
# 1. Amide formation
#    - Amine and acid likely commercially available
#    - Coupling reagents are common and shelf-stable
#    - Purification by crystallization or chromatography
#    - Scalable and robust with precedent
#
# 2. Nucleophilic aromatic substitution
#    - Fluorinated pyrimidine precursor may be expensive
#    - Fluoride sources like TBAF require anhydrous conditions
#    - Purification complicated by potential elimination
#    - Scale-up challenging due to moisture sensitivity
#
# 3. Pyrimidine ring formation
#    - Amidine and 1,3-dicarbonyl components readily available
#    - Cyclocondensation requires high temperature
#    - Purification by extraction/crystallization
#    - Fluorination step adds complexity but is precedented
#
# 4. C-N bond formation
#    - 2-Amino heterocycle precursor requires custom synthesis
#    - Selective amination may require transition metal catalyst
#    - Chromatographic purification likely needed
#    - Scale-up feasibility unclear without more precedent
#
# After practical review:
# - Amide coupling still stands out as most practical
# - SNAr approach is less feasible than initially thought
# - Pyrimidine synthesis is viable but longer
# - C-N bond approach is risky without extensive development
# </thinking>
#
# <thinking type="final_selection">
# Final proposal rankings:
# 1. Amide formation
#    - Most direct and convergent approach
#    - Relies on readily available building blocks
#    - Robust reaction with simple purification
#    - Confidence score: 0.85
#
# 2. Pyrimidine ring formation
#    - Enables late-stage diversification
#    - Cyclocondensation is scalable and precedented
#    - Fluorination adds a step but is known
#    - Confidence score: 0.70
#
# 3. C-N bond formation
#    - Modular approach with potential for library synthesis
#    - Selective amination may require screening
#    - Scale-up feasibility is biggest unknown
#    - Confidence score: 0.50
#
# After final validation:
# - The amide coupling is clearly the best single-step approach
# - Pyrimidine synthesis is a good backup if amide route fails
# - C-N bond approach is too underdeveloped to recommend
# - Overall the analysis balances innovation and pragmatism
# </thinking>
# </cot>
#
# <json>
# {
#   "thinking_process": [
#     {
#       "stage": "initial_assessment",
#       "analysis": "The target is a monocyclic aromatic heterocycle with a fused 6,6 ring system containing 3 nitrogens. It has an amide functional group and a fluorine substituent. There are no stereogenic centers. The molecule appears to be a fluorinated pyrimidine derivative.",
#       "reflection": "The structure is unambiguous with a valid SMILES string. The complexity is appropriate for single-step retrosynthesis. No hidden symmetry elements or unusual strain are apparent."
#     },
#     {
#       "stage": "strategic_analysis",
#       "analysis": "Four potential disconnection strategies were considered: 1) Amide C-N bond formation from a carboxylic acid and amine. 2) SNAr disconnection of the C-F bond. 3) Pyrimidine ring formation via cyclocondensation. 4) N1-C2 bond formation to give a 2-amino heterocycle.",
#       "reflection": "The amide formation seems most direct. The pyrimidine synthesis allows late-stage fluorination but is less convergent. The SNAr approach is limited by low fluoride reactivity. The C-N bond strategy is novel but untested."
#     },
#     {
#       "stage": "practical_considerations",
#       "analysis": "The amide coupling uses available starting materials, common reagents, and standard purification methods. The SNAr route requires anhydrous conditions and moisture-sensitive reagents. The pyrimidine synthesis is scalable but higher temperature. The C-N bond approach needs a custom precursor and has unknown scale-up feasibility.",
#       "reflection": "The amide coupling still appears most practical. The SNAr is less feasible than initially thought. The pyrimidine route is viable but longer. The C-N strategy is too risky without more development."
#     },
#     {
#       "stage": "final_selection",
#       "analysis": "The amide formation is ranked highest. It is direct, uses available building blocks, and is robust. The pyrimidine synthesis allows late-stage diversification and is scalable. The C-N approach is modular but underdeveloped. Confidence scores: amide (0.85), pyrimidine (0.70), C-N (0.50).",
#       "reflection": "The amide coupling is clearly the best single-step approach. Pyrimidine synthesis is a good backup. The C-N route is too immature to recommend first. The analysis balances innovation and pragmatism."
#     }
#   ],
#   "data": [
#     ["NC(=O)C1=NC(O)=NC=C1F", "OC1=NC=CC(F)=N1"],
#     ["NC1=NC(O)=NC(F)=C1", "C(=O)C(=O)CC(=O)C(N)=O"],
#     ["NC1=CC(F)=NC(O)=N1", "Cl"]
#   ],
#   "explanation": [
#     "Amide formation via coupling of 5-fluoropyrimidine-4,6-diol-2-carboxylic acid and ammonia",
#     "Cyclocondensation of 2-amino-6-fluoro-4-hydroxypyrimidine and a 1,3-dicarbonyl compound",
#     "N1-C2 bond formation via amination of 2-amino-6-fluoropyrimidin-4-ol with ammonia source"
#   ],
#   "confidence_scores": [
#     0.85,
#     0.70,
#     0.50
#   ]
# }
# </json>
# Molecule : OC1=NC=C(F)C(C(N)=O)=N1 is same as target molecule
# Obtained 2 valid pathways after validity test: [['NC1=NC(O)=NC(F)=C1', 'C(=O)C(=O)CC(=O)C(N)=O'], ['NC1=CC(F)=NC(O)=N1', 'Cl']]
# Output Pathways: [['NC1=NC(O)=NC(F)=C1', 'C(=O)C(=O)CC(=O)C(N)=O'], ['NC1=CC(F)=NC(O)=N1', 'Cl']],
#                 Output Explanations: ['Cyclocondensation of 2-amino-6-fluoro-4-hydroxypyrimidine and a 1,3-dicarbonyl compound', 'N1-C2 bond formation via amination of 2-amino-6-fluoropyrimidin-4-ol with ammonia source'],
#                     Output Confidence: [0.7, 0.5]
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:01:33 [info     ] AZ solved NC1=NC(O)=NC(F)=C1   filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=73
# 2025-02-14 19:01:33 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:03:42 [info     ] AZ solved C(=O)C(=O)CC(=O)C(N)=O filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=73
# 2025-02-14 19:03:42 [info     ] temp_stat: [True, True]        filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=63
# 2025-02-14 19:03:42 [info     ] breaking                       filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=70
# 2025-02-14 19:03:42 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:05:49 [info     ] AZ failed for NCC(=O)C1=CC(F)=NC(O)=N1, running LLM filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=31
# 00:35:49 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# Calling LLM with molecule: NCC(=O)C1=CC(F)=NC(O)=N1 and run: 0.0
# Calling claude-3-opus-20240229 with molecule: NCC(=O)C1=CC(F)=NC(O)=N1
# 00:36:55 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:36:55 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 2025-02-14 19:06:55 [info     ] LLM returned [['NCCO', 'OC(=O)C1=CC(F)=NC(O)=N1'], ['NCC(=O)Cl', 'OC1=CC(F)=NC(O)=N1']] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=53
# 2025-02-14 19:06:55 [info     ] LLM explained ['N-Alkylation: Alkyl chloride (NCC(=O)Cl) and ring NH (OC1=CC(F)=NC(O)=N1) combined via N-alkylation', 'Ring synthesis: β-Ketoester and guanidine precursors combined via condensation (not shown)'] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=54
# 2025-02-14 19:06:55 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# 2025-02-14 19:06:55 [info     ] AZ solved NCCO                 filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=73
# 2025-02-14 19:06:55 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Received response from LLM: Here is my retrosynthetic analysis for the target molecule with SMILES string NCC(=O)C1=CC(F)=NC(O)=N1:
#
# <cot>
# <thinking type="initial_assessment">
# Initial structural analysis:
# - The molecule has a linear carbon skeleton with a 6-membered heterocyclic ring
# - The ring contains 3 nitrogen atoms and 1 fluorine, with an exocyclic amide and hydroxyl group
# - The amide nitrogen has an ethylamine substituent
# - There are no stereogenic centers present
# - The molecule is relatively small with moderate complexity
#
# After further consideration:
# - The structure is unambiguous and the SMILES is valid
# - The ring system is a fluorinated hydroxypyrimidine with an acetamide substituent
# - Retrosynthetic analysis is warranted given the target's complexity
# </thinking>
#
# <thinking type="strategic_analysis">
# Potential strategic disconnections:
# 1. Amide bond: Disconnect the exocyclic amide C-N bond, giving an amine and a carboxylic acid or activated derivative
# 2. N-Alkylation: Disconnect the N-C bond of the ethylamine, giving an alkyl halide or sulfonate and the ring NH
# 3. Ring synthesis: Construct the pyrimidine ring from acyclic precursors, such as a β-ketoester and a guanidine
# 4. C-F bond formation: Install the fluorine late-stage via nucleophilic aromatic substitution on the pre-formed ring
# 5. C-OH bond formation: Introduce the hydroxyl group via oxidation or a protected alcohol
#
# After evaluating the strategies:
# - The amide disconnection seems most promising for convergency
# - N-alkylation could provide the ethylamine but requires a separate step
# - Ring synthesis offers a unique approach but may have regioselectivity challenges
# - Late-stage fluorination and hydroxylation are viable but linear
# </thinking>
#
# <thinking type="practical_considerations">
# Practical aspects of the proposed strategies:
#
# Amide disconnection:
# - Amine component is commercially available and inexpensive
# - Carboxylic acid could be accessed via oxidation of the corresponding aldehyde
# - Amide formation is well-precedented and scalable
# - Purification by crystallization or chromatography is straightforward
#
# N-Alkylation:
# - Both the alkyl halide and ring NH precursor are commercially available
# - Alkylation conditions (base, solvent) are well-established
# - Potential overalkylation could lower yield
# - Chromatographic purification likely required
#
# Ring synthesis:
# - β-Ketoester precursor may require multi-step synthesis
# - Guanidine component is commercially available but expensive
# - Condensation may give a mixture of regioisomers
# - Purification challenges due to high polarity of intermediates
#
# C-F and C-OH bond formation:
# - Requires pre-functionalized ring precursors
# - Nucleophilic fluorination conditions well-precedented but require dry conditions
# - Hydroxyl group could be installed via oxidation (e.g. NBS, then hydrolysis)
# - Polar intermediates may be challenging to purify
#
# After reviewing the practical considerations:
# - The amide disconnection emerges as the most practical and scalable
# - N-alkylation is also viable but requires an additional step
# - Ring synthesis is innovative but may face regioselectivity and purification issues
# - Late-stage fluorination and hydroxylation are feasible but linear and less convergent
# </thinking>
#
# <thinking type="final_selection">
# Final retrosynthetic strategies:
# 1. Amide disconnection
#    - Most promising approach balancing convergency and simplicity
#    - Amine and carboxylic acid precursors are readily available
#    - Amide formation is robust and scalable
#    - High confidence in success (0.85)
#
# 2. N-Alkylation
#    - Viable linear approach
#    - Alkyl halide and ring NH are commercially available
#    - Alkylation is well-precedented but selectivity may be moderate
#    - Reasonable confidence in success (0.70)
#
# 3. Ring synthesis
#    - Innovative convergent approach
#    - β-Ketoester requires synthesis; guanidine is expensive
#    - Condensation may face regioselectivity challenges
#    - Moderate confidence in success (0.60)
#
# After final validation:
# - The amide disconnection is the best balance of innovation and pragmatism
# - N-alkylation is a viable backup if amide route fails
# - Ring synthesis deprioritized due to practical challenges
# - Overall the analysis is thorough and the recommendations are reasonable
# </thinking>
# </cot>
#
# <json>
# {
#   "thinking_process": [
#     {
#       "stage": "initial_assessment",
#       "analysis": "The target molecule has a linear carbon skeleton with a fluorinated hydroxypyrimidine ring bearing an exocyclic acetamide. The amide nitrogen has an ethylamine substituent. There are no stereogenic centers and the molecule has moderate complexity.",
#       "reflection": "The structure is unambiguous with a valid SMILES string. Retrosynthetic analysis is warranted given the target's complexity."
#     },
#     {
#       "stage": "strategic_analysis",
#       "analysis": "Five potential strategic disconnections were identified: 1) amide C-N bond, 2) N-alkylation of ethylamine, 3) pyrimidine ring synthesis, 4) late-stage C-F bond formation, and 5) late-stage C-OH bond formation.",
#       "reflection": "The amide disconnection is most promising for convergency. N-alkylation is viable but requires an extra step. Ring synthesis is innovative but may have selectivity issues. Fluorination and hydroxylation are linear approaches."
#     },
#     {
#       "stage": "practical_considerations",
#       "analysis": "The amide disconnection uses available starting materials and robust reactions, making it practical and scalable. N-alkylation is also viable with precedented conditions. Ring synthesis may face purification challenges. Fluorination and hydroxylation require pre-functionalized precursors.",
#       "reflection": "Evaluating the practical aspects, the amide route emerges as the most feasible and scalable. N-alkylation is a viable backup. Ring synthesis is deprioritized due to potential issues. Late-stage fluorination and hydroxylation are linear and less preferred."
#     },
#     {
#       "stage": "final_selection",
#       "analysis": "The recommended strategies are: 1) Amide disconnection (confidence 0.85) due to convergency, available materials and precedent. 2) N-alkylation (confidence 0.70) as a viable linear backup. 3) Ring synthesis (confidence 0.60) deprioritized for practical challenges.",
#       "reflection": "The amide disconnection provides the best balance of innovation and pragmatism. N-alkylation is a reasonable alternative. The analysis is thorough and recommendations are well-justified."
#     }
#   ],
#   "data": [
#     ["NCC(=O)C1=CC(F)=NC(O)=N1"],
#     ["NCCO", "OC(=O)C1=CC(F)=NC(O)=N1"],
#     ["NCC(=O)Cl", "OC1=CC(F)=NC(O)=N1"]
#   ],
#   "explanation": [
#     "Amide disconnection: Amine (NCCO) and carboxylic acid (OC(=O)C1=CC(F)=NC(O)=N1) combined via amide coupling",
#     "N-Alkylation: Alkyl chloride (NCC(=O)Cl) and ring NH (OC1=CC(F)=NC(O)=N1) combined via N-alkylation",
#     "Ring synthesis: β-Ketoester and guanidine precursors combined via condensation (not shown)"
#   ],
#   "confidence_scores": [
#     0.85,
#     0.70,
#     0.60
#   ]
# }
# </json>
# Molecule : NCC(=O)C1=CC(F)=NC(O)=N1 is same as target molecule
# Obtained 2 valid pathways after validity test: [['NCCO', 'OC(=O)C1=CC(F)=NC(O)=N1'], ['NCC(=O)Cl', 'OC1=CC(F)=NC(O)=N1']]
# Output Pathways: [['NCCO', 'OC(=O)C1=CC(F)=NC(O)=N1'], ['NCC(=O)Cl', 'OC1=CC(F)=NC(O)=N1']],
#                 Output Explanations: ['N-Alkylation: Alkyl chloride (NCC(=O)Cl) and ring NH (OC1=CC(F)=NC(O)=N1) combined via N-alkylation', 'Ring synthesis: β-Ketoester and guanidine precursors combined via condensation (not shown)'],
#                     Output Confidence: [0.7, 0.6]
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:08:52 [info     ] AZ failed for OC(=O)C1=CC(F)=NC(O)=N1, running LLM filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=31
# 00:38:52 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# Calling LLM with molecule: OC(=O)C1=CC(F)=NC(O)=N1 and run: 0.0
# Calling claude-3-opus-20240229 with molecule: OC(=O)C1=CC(F)=NC(O)=N1
# 00:40:10 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:40:10 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 2025-02-14 19:10:10 [info     ] LLM returned [['Nc1c(F)cnc(N)c1', 'C(=O)C(=O)O'], ['Nc1c(F)cnc(N)c1', 'C(=O)Cl']] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=53
# 2025-02-14 19:10:10 [info     ] LLM explained ['Condensation of 2-fluoropyridine-3,4-diamine with oxalic acid, followed by cyclization', 'SNAr reactions on 2-chloro-6-fluoropyridine-3,4-dicarbonitrile to form diamine, then reaction with phosgene'] filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=54
# 2025-02-14 19:10:10 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Received response from LLM: Here is my retrosynthetic analysis for the target molecule with SMILES string OC(=O)C1=CC(F)=NC(O)=N1:
#
# <cot>
# <thinking type="initial_assessment">
# Initial structural analysis:
# - The molecule has a 6-membered heterocyclic ring with 3 nitrogen atoms
# - The ring contains an ortho-fluoropyridine moiety fused to a hydantoin ring
# - There is a carboxylic acid functional group attached at the 2-position of the pyridine
# - The molecule is planar with no stereogenic centers
# - The hydantoin ring can be considered a cyclic urea with an additional carbonyl
#
# Reflection:
# The structure appears to be correctly identified with no hidden symmetry or strain. The hydantoin and ortho-fluoropyridine moieties are the key structural features to focus on for disconnection.
# </thinking>
#
# <thinking type="strategic_analysis">
# Potential disconnection strategies:
# 1. Disconnect the C-C bond between the carboxylic acid and pyridine ring
#    - This gives a 2-fluoropyridine-3,4-diamine and oxalic acid as precursors
#    - The diamine could be condensed with a C2 unit like ethyl oxalate, followed by hydrolysis
#    - Precedent exists for related pyridine/hydantoin ring formations
#
# 2. Disconnect the C-N bond of the hydantoin ring opposite the pyridine
#    - This gives a 2-carboxy-3-amino-6-fluoropyridine-4-carboxamide intermediate
#    - The intermediate could be formed by amide coupling of a 2-carboxy-3-amino-6-fluoropyridine-4-carboxylic acid
#    - A final cyclization by attack of the amide NH on the pyridine carboxylic acid would form the hydantoin
#
# 3. Disconnect both C-N bonds of the hydantoin ring
#    - This gives a 2-carboxy-6-fluoropyridine-3,4-diamine precursor
#    - The diamine could be reacted with phosgene or a phosgene equivalent to form the hydantoin directly
#    - The 2-carboxy-6-fluoropyridine-3,4-diamine could come from SNAr reactions on 2-chloro-6-fluoropyridine-3,4-dicarbonitrile
#
# Reflection:
# The three proposed strategies each have merits and drawbacks. The first route is most convergent but relies on the challenging condensation/cyclization. The second route is stepwise but avoids difficult SNAr steps. The third is most direct but uses hazardous phosgene. Literature precedent should be carefully evaluated for each.
# </thinking>
#
# <thinking type="practical_considerations">
# Practical evaluation of proposed routes:
# 1. Oxalic acid route
#    - Both 2-fluoropyridine-3,4-diamine and oxalic acid are commercially available and inexpensive
#    - The condensation/cyclization may require high temperatures and long reaction times
#    - Purification of the hydantoin product could be challenging due to polarity
#
# 2. Stepwise hydantoin formation
#    - The 2-carboxy-3-amino-6-fluoropyridine-4-carboxylic acid intermediate would need to be custom synthesized
#    - Amide coupling and cyclization should be achievable under mild conditions
#    - Potential for epimerization of the carboxylic acid stereocenters during cyclization
#
# 3. Phosgene route
#    - 2-Chloro-6-fluoropyridine-3,4-dicarbonitrile is commercially available but expensive
#    - The SNAr reactions to install the diamine may require harsh conditions
#    - Phosgene is highly toxic and requires special handling, but should effect rapid hydantoin formation
#    - The hydantoin product may be unstable to hydrolysis during aqueous workup
#
# Reflection:
# The oxalic acid route seems most practical from a cost and scale-up perspective, if the key condensation can be optimized. The stepwise route offers the mildest conditions but the most steps. The phosgene route is most direct but brings significant safety concerns. A thorough survey of reaction conditions and precedent is warranted.
# </thinking>
#
# <thinking type="final_selection">
# Final retrosynthetic proposals ranked by overall preference:
#
# 1. Oxalic acid route
#    - Balances convergency, cost, and practicality
#    - Key risk is the final condensation/cyclization step
#    - Optimization of this step should be prioritized
#    - Confidence score: 0.70
#
# 2. Stepwise hydantoin formation
#    - Offers greatest control and mildest conditions
#    - Requires the most linear steps and novel intermediates
#    - Potential for epimerization needs to be evaluated
#    - Confidence score: 0.60
#
# 3. Phosgene route
#    - Most direct and potentially highest yielding
#    - Significant safety concerns with phosgene
#    - SNAr reactions to form diamine may be challenging
#    - Confidence score: 0.40
#
# Reflection:
# The oxalic acid route is recommended as the best balance of efficiency and practicality, with acceptable risk. The stepwise approach is a viable backup if the condensation/cyclization proves unworkable. The phosgene route, while most direct, brings substantial safety issues that lower its desirability. Further literature validation is recommended for all routes before commencing lab work.
# </thinking>
# </cot>
#
# <json>
# {
#   "thinking_process": [
#     {
#       "stage": "initial_assessment",
#       "analysis": "The molecule has a 6-membered heterocyclic ring with 3 nitrogen atoms. The ring contains an ortho-fluoropyridine moiety fused to a hydantoin ring. There is a carboxylic acid functional group attached at the 2-position of the pyridine. The molecule is planar with no stereogenic centers. The hydantoin ring can be considered a cyclic urea with an additional carbonyl.",
#       "reflection": "The structure appears to be correctly identified with no hidden symmetry or strain. The hydantoin and ortho-fluoropyridine moieties are the key structural features to focus on for disconnection."
#     },
#     {
#       "stage": "strategic_analysis",
#       "analysis": "Three potential disconnection strategies were identified: 1) Disconnect C-C bond between carboxylic acid and pyridine, condensing resulting diamine with a C2 unit. 2) Disconnect C-N bond of hydantoin opposite pyridine, forming intermediate by amide coupling and cyclization. 3) Disconnect both C-N bonds of hydantoin, reacting resulting diamine with phosgene.",
#       "reflection": "The three proposed strategies each have merits and drawbacks. The first route is most convergent but relies on the challenging condensation/cyclization. The second route is stepwise but avoids difficult SNAr steps. The third is most direct but uses hazardous phosgene. Literature precedent should be carefully evaluated for each."
#     },
#     {
#       "stage": "practical_considerations",
#       "analysis": "Practical evaluation: 1) Oxalic acid route uses cheap starting materials but has a difficult condensation step and potential purification challenges. 2) Stepwise route requires a custom intermediate and has potential for epimerization, but uses mild conditions. 3) Phosgene route is most direct but uses highly toxic phosgene and the product may be unstable to aqueous workup.",
#       "reflection": "The oxalic acid route seems most practical from a cost and scale-up perspective, if the key condensation can be optimized. The stepwise route offers the mildest conditions but the most steps. The phosgene route is most direct but brings significant safety concerns. A thorough survey of reaction conditions and precedent is warranted."
#     },
#     {
#       "stage": "final_selection",
#       "analysis": "Final rankings: 1) Oxalic acid route balances convergency, cost and practicality. Key risk is condensation/cyclization optimization (confidence 0.70). 2) Stepwise route offers greatest control and mildest conditions but is linear and requires novel intermediates. Epimerization potential needs evaluation (confidence 0.60). 3) Phosgene route is most direct but has significant safety issues (confidence 0.40).",
#       "reflection": "The oxalic acid route is recommended as the best balance of efficiency and practicality, with acceptable risk. The stepwise approach is a viable backup if the condensation/cyclization proves unworkable. The phosgene route, while most direct, brings substantial safety issues that lower its desirability. Further literature validation is recommended for all routes before commencing lab work."
#     }
#   ],
#   "data": [
#     ["Nc1c(F)cnc(N)c1", "C(=O)C(=O)O"],
#     ["NC(=O)c1cnc(F)c(C(=O)O)c1N"],
#     ["Nc1c(F)cnc(N)c1", "C(=O)Cl"]
#   ],
#   "explanation": [
#     "Condensation of 2-fluoropyridine-3,4-diamine with oxalic acid, followed by cyclization",
#     "Amide coupling of 2-carboxy-3-amino-6-fluoropyridine-4-carboxylic acid, then intramolecular cyclization",
#     "SNAr reactions on 2-chloro-6-fluoropyridine-3,4-dicarbonitrile to form diamine, then reaction with phosgene"
#   ],
#   "confidence_scores": [
#     0.70,
#     0.60,
#     0.40
#   ]
# }
# </json>
# Obtained 2 valid pathways after validity test: [['Nc1c(F)cnc(N)c1', 'C(=O)C(=O)O'], ['Nc1c(F)cnc(N)c1', 'C(=O)Cl']]
# Output Pathways: [['Nc1c(F)cnc(N)c1', 'C(=O)C(=O)O'], ['Nc1c(F)cnc(N)c1', 'C(=O)Cl']],
#                 Output Explanations: ['Condensation of 2-fluoropyridine-3,4-diamine with oxalic acid, followed by cyclization', 'SNAr reactions on 2-chloro-6-fluoropyridine-3,4-dicarbonitrile to form diamine, then reaction with phosgene'],
#                     Output Confidence: [0.7, 0.4]
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:10:57 [info     ] AZ solved Nc1c(F)cnc(N)c1      filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=73
# 2025-02-14 19:10:57 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_002417_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:11:06 [info     ] AZ solved C(=O)C(=O)O          filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=73
# 2025-02-14 19:11:06 [info     ] temp_stat: [True, True]        filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=63
# 2025-02-14 19:11:06 [info     ] breaking                       filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=70
# 2025-02-14 19:11:06 [info     ] temp_stat: [True, True]        filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=63
# 2025-02-14 19:11:06 [info     ] breaking                       filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=70
# 2025-02-14 19:11:06 [info     ] temp_stat: [True, True]        filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=63
# 2025-02-14 19:11:06 [info     ] breaking                       filename=rec_prithvi.py job_id=20250215_002417_96180 lineno=70
# 00:41:10 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:41:14 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# ...
# } filename=metadata.py job_id=20250215_004435_96180 lineno=166
# 00:46:09 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:46:09 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:46:12 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:16:12 [info     ] Received response from LLM: {
#   "temperature": "0°C",
#   "pressure": "1 atm",
#   "solvent": "Water (H2O)",
#   "time": "30 minutes"
# } filename=metadata.py job_id=20250215_004435_96180 lineno=284
# 00:46:12 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:46:12 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:46:19 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:16:19 [info     ] Received response from LLM: {
#   "literature_reaction": "Reduction of oximes to primary amines using sodium borohydride (NaBH4) in methanol or ethanol",
#   "explanation": "This is a reduction reaction of an oxime (R1R2C=NOH) to a primary amine (R1R2CH-NH2) using sodium borohydride as the reducing agent. The reaction is typically carried out in protic solvents like methanol or ethanol at room temperature or with mild heating. In this case, the oxime starting material has an additional acyl chloride functional group, which should be compatible with the reaction conditions."
# } filename=metadata.py job_id=20250215_004435_96180 lineno=358
# 00:46:19 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:46:19 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:46:24 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:16:24 [info     ] Received response from LLM: {
#   "data": [],
#   "explanation": ["This reaction does not require any additional reagents. It is a simple acyl chloride formation from the carboxylic acid CCC(=O)Cl, with the nitrosamine CC(C)CCON=O acting as a leaving group. The reaction likely proceeds under mild conditions without the need for catalysts or other reagents."]
# } filename=metadata.py job_id=20250215_004435_96180 lineno=166
# 00:46:24 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:46:24 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:46:29 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:16:29 [info     ] Received response from LLM: {
#   "temperature": "0-25 °C",
#   "pressure": "1 atm",
#   "solvent": "No solvent needed",
#   "time": "Rapid reaction, likely complete within minutes"
# } filename=metadata.py job_id=20250215_004435_96180 lineno=284
# 00:46:29 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:46:29 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:46:36 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:46:36 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# 2025-02-14 19:16:36 [info     ] Received response from LLM: {
#   "literature_reaction": "Acid chloride formation from carboxylic acid using nitrosyl chloride (Cl-N=O)",
#   "explanation": "The reaction between a carboxylic acid (CCC(=O)Cl) and nitrosyl chloride (CC(C)CCON=O) rapidly forms an acid chloride (CC(=NO)C(=O)Cl) at 0-25 °C without solvent. The nitrosyl group (-N=O) is transferred from the nitrosyl chloride to the acid, displacing the hydroxyl group and forming the acid chloride. This is an example of a dehydration reaction using a specialized dehydrating agent."
# } filename=metadata.py job_id=20250215_004435_96180 lineno=358
# Langfuse Layer Logging - logging success
# Retrosynthesis result: {'dependencies': {'1': ['2'], '2': ['3'], '3': []}, 'steps': [{'step': '1', 'reactants': [{'smiles': 'CC(N)C(=O)Cl', 'reactant_metadata': {'name': '', 'chemical_formula': 'C3H6ClNO', 'mass': 107.013791492}}, {'smiles': 'Cc1cccc(C)c1N', 'reactant_metadata': {'name': '', 'chemical_formula': 'C8H11N', 'mass': 121.08914935199999}}], 'reagents': [], 'products': [{'smiles': 'Cc1cccc(C)c1NC(=O)C(C)N', 'product_metadata': {'name': '', 'chemical_formula': 'C11H16N2O', 'mass': 192.126263132}}], 'conditions': {'temperature': '0-25 °C', 'pressure': 'Ambient pressure', 'solvent': 'Dichloromethane, chloroform, or other aprotic solvent', 'time': '1-4 hours'}, 'reactionmetrics': [{'scalabilityindex': '9', 'confidenceestimate': 0.99, 'closestliterature': 'Schotten-Baumannreaction of an amine with an acyl chloride'}]}, {'step': '2', 'reactants': [{'smiles': 'CC(=NO)C(=O)Cl', 'reactant_metadata': {'name': '', 'chemical_formula': 'C3H4ClNO2', 'mass': 120.993056048}}], 'reagents': [{'smiles': 'O', 'reagent_metadata': {'name': '', 'chemical_formula': 'H2O', 'mass': 18.010564684}}], 'products': [{'smiles': 'CC(N)C(=O)Cl', 'product_metadata': {'name': '', 'chemical_formula': 'C3H6ClNO', 'mass': 107.013791492}}], 'conditions': {'temperature': '0°C', 'pressure': '1 atm', 'solvent': 'Water (H2O)', 'time': '30 minutes'}, 'reactionmetrics': [{'scalabilityindex': '9', 'confidenceestimate': 0.99, 'closestliterature': 'Reduction of oximes to primary amines using sodium borohydride (NaBH4) in methanol or ethanol'}]}, {'step': '3', 'reactants': [{'smiles': 'CCC(=O)Cl', 'reactant_metadata': {'name': '', 'chemical_formula': 'C3H5ClO', 'mass': 92.00289246}}, {'smiles': 'CC(C)CCON=O', 'reactant_metadata': {'name': '', 'chemical_formula': 'C5H11NO2', 'mass': 117.078978592}}], 'reagents': [], 'products': [{'smiles': 'CC(=NO)C(=O)Cl', 'product_metadata': {'name': '', 'chemical_formula': 'C3H4ClNO2', 'mass': 120.993056048}}], 'conditions': {'temperature': '0-25 °C', 'pressure': '1 atm', 'solvent': 'No solvent needed', 'time': 'Rapid reaction, likely complete within minutes'}, 'reactionmetrics': [{'scalabilityindex': '9', 'confidenceestimate': 0.87, 'closestliterature': 'Acid chloride formation from carboxylic acid using nitrosyl chloride (Cl-N=O)'}]}]}
# 2025-02-14 19:16:36 [info     ] -------------------------------------------------- filename=main.py lineno=29
# 2025-02-14 19:16:36 [info     ] Application initialization complete filename=main.py lineno=30
# 2025-02-14 19:16:36 [info     ] Starting new synthesis job 20250215_004636_96180 for molecule COC1=CC(C(O)C(C)N)=C(OC)C=C1 filename=prithvi.py job_id=20250215_004636_96180 lineno=31
# 2025-02-14 19:16:36 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20250215_004636_96180 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Running Methoxamine
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2025-02-14 19:17:45 [info     ] AZ solved COC1=CC(C(O)C(C)N)=C(OC)C=C1 filename=rec_prithvi.py job_id=20250215_004636_96180 lineno=73
# 00:47:46 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:47:51 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 00:47:51 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# 2025-02-14 19:17:51 [info     ] Received response from LLM: {
#   "data": ["[H][H]"],
#   "explanation": ["This is a nitro reduction reaction, converting the nitro group (R-NO2) to an amine (R-NH2). The reaction requires a reducing agent such as hydrogen gas (H2) with a metal catalyst like Pd/C or Raney Ni. The reaction is typically performed under elevated hydrogen pressure."]
# } filename=metadata.py job_id=20250215_004636_96180 lineno=166
# Langfuse Layer Logging - logging success
# 00:47:51 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:47:55 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:17:55 [info     ] Received response from LLM: {
#   "temperature": "Room temperature (20-25 °C)",
#   "pressure": "Atmospheric pressure",
#   "solvent": "Ethanol or methanol",
#   "time": "1-2 hours"
# } filename=metadata.py job_id=20250215_004636_96180 lineno=284
# 00:47:55 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:47:55 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:48:03 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:18:03 [info     ] Received response from LLM: {
#   "literature_reaction": "Reduction of a nitro group to an amine using hydrogen gas and a metal catalyst",
#   "explanation": "This reaction involves the reduction of a nitro group (R-NO2) to a primary amine (R-NH2) using molecular hydrogen (H2) as the reducing agent. The reaction typically requires a metal catalyst such as palladium on carbon (Pd/C) or Raney nickel. The solvent is usually an alcohol like ethanol or methanol, and the reaction is carried out at room temperature and atmospheric pressure. The reaction time is generally 1-2 hours for complete conversion."
# } filename=metadata.py job_id=20250215_004636_96180 lineno=358
# 00:48:03 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:48:03 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:48:10 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:18:10 [info     ] Received response from LLM: {
#   "data": ["[OH-]"],
#   "explanation": ["This is a base-catalyzed aldol addition reaction. The nitroethane anion, formed by deprotonation with hydroxide, acts as the nucleophile and adds to the aldehyde. The resulting alkoxide is then protonated to give the β-hydroxy nitroalkane product."]
# } filename=metadata.py job_id=20250215_004636_96180 lineno=166
# 00:48:10 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:48:10 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:48:15 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:18:15 [info     ] Received response from LLM: {
#   "temperature": "0-5 °C",
#   "pressure": "Atmospheric pressure",
#   "solvent": "Ethanol",
#   "time": "30 minutes to 2 hours"
# } filename=metadata.py job_id=20250215_004636_96180 lineno=284
# 00:48:15 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# 00:48:15 - LiteLLM:INFO: utils.py:2870 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 00:48:24 - LiteLLM:INFO: utils.py:1073 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 2025-02-14 19:18:24 [info     ] Received response from LLM: {
#   "literature_reaction": "Aldol addition of a nitroalkane to an aromatic aldehyde",
#   "explanation": "This is an aldol addition reaction between a nitroalkane (nitroethane) and an aromatic aldehyde (3,4-dimethoxybenzaldehyde) under basic conditions using hydroxide as the base. The reaction likely proceeds via deprotonation of the nitroalkane to form a resonance-stabilized nitronate anion, which then undergoes nucleophilic addition to the aldehyde carbonyl group. Key conditions include low temperature (0-5 °C) to control the selectivity, and a protic solvent (ethanol) to facilitate proton transfer steps. The reaction time of 30 min to 2 h is typical for this type of aldol addition."
# } filename=metadata.py job_id=20250215_004636_96180 lineno=358
# 00:48:24 - LiteLLM:INFO: langfuse.py:297 - Langfuse Layer Logging - logging success
# Langfuse Layer Logging - logging success
# Retrosynthesis result: {'dependencies': {'1': ['2'], '2': []}, 'steps': [{'step': '1', 'reactants': [{'smiles': 'COc1ccc(OC)c(C(O)C(C)[N+](=O)[O-])c1', 'reactant_metadata': {'name': '', 'chemical_formula': 'C11H15NO5', 'mass': 241.09502258}}], 'reagents': [{'smiles': '[H][H]', 'reagent_metadata': {'name': '', 'chemical_formula': 'H2', 'mass': 2.015650064}}], 'products': [{'smiles': 'COc1ccc(OC)c(C(O)C(C)N)c1', 'product_metadata': {'name': '', 'chemical_formula': 'C11H17NO3', 'mass': 211.120843404}}], 'conditions': {'temperature': 'Room temperature (20-25 °C)', 'pressure': 'Atmospheric pressure', 'solvent': 'Ethanol or methanol', 'time': '1-2 hours'}, 'reactionmetrics': [{'scalabilityindex': '8', 'confidenceestimate': 0.73, 'closestliterature': 'Reduction of a nitro group to an amine using hydrogen gas and a metal catalyst'}]}, {'step': '2', 'reactants': [{'smiles': 'CC[N+](=O)[O-]', 'reactant_metadata': {'name': '', 'chemical_formula': 'C2H5NO2', 'mass': 75.0320284}}, {'smiles': 'COc1ccc(OC)c(C=O)c1', 'reactant_metadata': {'name': '', 'chemical_formula': 'C9H10O3', 'mass': 166.06299418}}], 'reagents': [{'smiles': '[OH-]', 'reagent_metadata': {'name': '', 'chemical_formula': 'HO-', 'mass': 17.00328823191}}], 'products': [{'smiles': 'COc1ccc(OC)c(C(O)C(C)[N+](=O)[O-])c1', 'product_metadata': {'name': '', 'chemical_formula': 'C11H15NO5', 'mass': 241.09502258}}], 'conditions': {'temperature': '0-5 °C', 'pressure': 'Atmospheric pressure', 'solvent': 'Ethanol', 'time': '30 minutes to 2 hours'}, 'reactionmetrics': [{'scalabilityindex': '9', 'confidenceestimate': 0.75, 'closestliterature': 'Aldol addition of a nitroalkane to an aromatic aldehyde'}]}]}

# %%
# for mol in mols:
#     molecule = mols[mol]
#     print(f"Running {mol}")
#     try:
#         res_dict = run_prithvi(molecule)
#         with open(f"{root_dir}/results/mols/{mol}.json", "w") as f:
#             json.dump(res_dict, f, indent=4)
#     except Exception as e:
#         print("Error in molecule:", mol)
#         print("Error:", e)

# %%
for mol in mols_hard:
    molecule = mols_hard[mol]
    print(f"Running {mol}")
    # try:
    #     res_dict = run_prithvi(molecule)
    #     with open(f"{root_dir}/results/mols_hard/{mol}.json", "w") as f:
    #         json.dump(res_dict, f, indent=4)
    # except Exception as e:
    #     print("Error in molecule:", mol)
    #     print("Error:", e)
    res_dict = main(molecule)  #, llm="o1-preview-2024-09-12")
    with open(f"{root_dir}/results/mols_hard/{mol}_claude_cot.json", "w") as f:
        json.dump(res_dict, f, indent=4)
# Out:
# 2024-12-24 05:44:14 [info     ] -------------------------------------------------- filename=main.py lineno=29
# 2024-12-24 05:44:14 [info     ] Application initialization complete filename=main.py lineno=30
# 2024-12-24 05:44:14 [info     ] Starting new synthesis job 20241224_111414_17923 for molecule CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O filename=prithvi.py job_id=20241224_111414_17923 lineno=31
# 2024-12-24 05:44:14 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20241224_111414_17923 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Running dalbavancin
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2024-12-24 05:45:04 [info     ] AZ failed for CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O, running LLM filename=rec_prithvi.py job_id=20241224_111414_17923 lineno=31
# 2024-12-24 05:45:04 [info     ] Calling LLM with molecule: CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O and run: 0.0 filename=llm.py job_id=20241224_111414_17923 lineno=154
# 11:15:04 - LiteLLM:INFO: utils.py:2723 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 11:16:08 - LiteLLM:INFO: utils.py:890 - Wrapper: Completed Call, calling success_handler
# Wrapper: Completed Call, calling success_handler
# 11:16:08 - LiteLLM:INFO: langfuse.py:294 - Langfuse Layer Logging - logging success
# 2024-12-24 05:46:08 [info     ] Received response from LLM: Here is my retrosynthetic analysis of the given molecule:
#
# <cot>
# <thinking>
# The target molecule is a complex glycopeptide antibiotic, likely related to vancomycin. Key structural features include:
# - A heptapeptide backbone with several non-proteinogenic amino acids
# - Aromatic rings, including chlorinated tyrosine residues, that form cross-links
# - Disaccharide attached to one of the tyrosine residues
# - A long aliphatic chain, likely a lipid tail, attached to the N-terminus via an amide bond
# </thinking>
#
# <thinking>
# One approach would be to disconnect the lipid tail from the heptapeptide. This could be accomplished by hydrolysis of the amide bond. The resulting fragments would be the free heptapeptide and the carboxylic acid of the lipid.
# </thinking>
#
# <thinking>
# Another key disconnection would be between the disaccharide and the peptide. A glycosidic bond connects these two fragments. Selective hydrolysis, possibly enzymatic, could cleave this bond to give the free disaccharide and the peptide with a free phenol.
# </thinking>
#
# <thinking>
# The biaryl and biaryl ether crosslinks are another key feature. These could arise from oxidative couplings of aromatic side-chains, likely mediated by cytochrome P450 enzymes or similar oxidases. Disconnection of these linkages greatly simplifies the peptide structure.
# </thinking>
#
# <thinking>
# Finally, the peptide backbone could be simplified by disconnecting at the amide bonds. This would give the individual amino acid building blocks. Some of the unusual amino acids, like the chlorinated tyrosine, may need to be synthesized separately before peptide coupling.
# </thinking>
#
# </cot>
#
# <json>
# {
#   "data": [
#     ["CC(C)CCCCCCCCC(=O)O", "N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O"],
#     ["CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1O)O)O)O", "OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O"],
#     ["CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=CC=C2OC4=CC(=CC=C4)O)O)O)O", "N[C@@H](C1=C(C(=CC(=C1)O)O[C@@H]2[C@H]([C@H]([C@@H]([C@H](O2)CO)O)O)O)C3=C(C=CC(=C3)[C@H](C(=O)N4)NC(=O)[C@@H]5NC(=O)[C@@H]6C7=C(C(=CC(=C7)OC7=C(C=CC(=C7)[C@H](C(=O)N[C@H](CC7=CC=C(O8)C=C7)C(=O)N6)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O"],
#     ["N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](C(=O)N[C@@H](C1=C(C=CC(=C1)Cl)O)C(=O)N[C@@H](C1=C(C(=CC(=C1)O)O[C@@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)Cl)C(=O)N[C@@H](C1=C(C=CC(=C1)[C@H](C(=O)N[C@@H](C(=O)N[C@@H](C(=O)NCCCN(C)C)CC1=CC=C(O)C=C1)CC(C)C)O)O)C(=O)O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CC(C)C)NC(=O)CCC(C)C", "CC(C)CCCCCCCCC(=O)Cl"]
#   ],
#   "explanation": [
#     "Disconnection of the lipid tail amide bond, giving the carboxylic acid of the lipid and the free heptapeptide. This could be accomplished by hydrolysis.",
#     "Disconnection of the glycosidic bond between the disaccharide and the peptide. Selective hydrolysis, possibly enzymatic, could cleave this bond.",
#     "Disconnection of the biaryl and biaryl ether crosslinks. These likely form via oxidative couplings, possibly mediated by P450 enzymes. Removes crosslinks and greatly simplifies the peptide.",
#     "Disconnection of the peptide backbone at the amide bonds, giving the individual amino acid building blocks. The lipid tail is also disconnected from its amino acid by replacing the amide with an acid chloride, implying an amide coupling reaction. Some non-proteinogenic amino acids may need to be synthesized separately."
#   ],
#   "confidence_scores": [
#     0.9,
#     0.8,
#     0.7,
#     0.6
#   ]
# }
# </json> filename=llm.py job_id=20241224_111414_17923 lineno=68
# Langfuse Layer Logging - logging success
# 2024-12-24 05:46:08 [info     ] Molecule : CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O is invalid or cannot be parsed filename=utils_molecule.py job_id=20241224_111414_17923 lineno=123
# 2024-12-24 05:46:08 [info     ] Molecule : CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O is invalid or cannot be parsed filename=utils_molecule.py job_id=20241224_111414_17923 lineno=123
# 2024-12-24 05:46:08 [info     ] Molecule : CC(C)CCCCCCCCC(=O)N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O is invalid or cannot be parsed filename=utils_molecule.py job_id=20241224_111414_17923 lineno=123
# 2024-12-24 05:46:08 [info     ] Obtained 2 valid pathways after validity test: [['CC(C)CCCCCCCCC(=O)O', 'N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O'], ['N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](C(=O)N[C@@H](C1=C(C=CC(=C1)Cl)O)C(=O)N[C@@H](C1=C(C(=CC(=C1)O)O[C@@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)Cl)C(=O)N[C@@H](C1=C(C=CC(=C1)[C@H](C(=O)N[C@@H](C(=O)N[C@@H](C(=O)NCCCN(C)C)CC1=CC=C(O)C=C1)CC(C)C)O)O)C(=O)O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CC(C)C)NC(=O)CCC(C)C', 'CC(C)CCCCCCCCC(=O)Cl']] filename=utils_molecule.py job_id=20241224_111414_17923 lineno=144
# 2024-12-24 05:46:08 [info     ] Output Pathways: [['CC(C)CCCCCCCCC(=O)O', 'N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O'], ['N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](C(=O)N[C@@H](C1=C(C=CC(=C1)Cl)O)C(=O)N[C@@H](C1=C(C(=CC(=C1)O)O[C@@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)Cl)C(=O)N[C@@H](C1=C(C=CC(=C1)[C@H](C(=O)N[C@@H](C(=O)N[C@@H](C(=O)NCCCN(C)C)CC1=CC=C(O)C=C1)CC(C)C)O)O)C(=O)O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CC(C)C)NC(=O)CCC(C)C', 'CC(C)CCCCCCCCC(=O)Cl']],
#                             Output Explanations: ['Disconnection of the lipid tail amide bond, giving the carboxylic acid of the lipid and the free heptapeptide. This could be accomplished by hydrolysis.', 'Disconnection of the peptide backbone at the amide bonds, giving the individual amino acid building blocks. The lipid tail is also disconnected from its amino acid by replacing the amide with an acid chloride, implying an amide coupling reaction. Some non-proteinogenic amino acids may need to be synthesized separately.'],
#                                 Output Confidence: [0.9, 0.6] filename=llm.py job_id=20241224_111414_17923 lineno=169
# 2024-12-24 05:46:08 [info     ] LLM returned [['CC(C)CCCCCCCCC(=O)O', 'N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O'], ['N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](C(=O)N[C@@H](C1=C(C=CC(=C1)Cl)O)C(=O)N[C@@H](C1=C(C(=CC(=C1)O)O[C@@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)Cl)C(=O)N[C@@H](C1=C(C=CC(=C1)[C@H](C(=O)N[C@@H](C(=O)N[C@@H](C(=O)NCCCN(C)C)CC1=CC=C(O)C=C1)CC(C)C)O)O)C(=O)O)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CC(C)C)NC(=O)CCC(C)C', 'CC(C)CCCCCCCCC(=O)Cl']] filename=rec_prithvi.py job_id=20241224_111414_17923 lineno=53
# 2024-12-24 05:46:08 [info     ] LLM explained ['Disconnection of the lipid tail amide bond, giving the carboxylic acid of the lipid and the free heptapeptide. This could be accomplished by hydrolysis.', 'Disconnection of the peptide backbone at the amide bonds, giving the individual amino acid building blocks. The lipid tail is also disconnected from its amino acid by replacing the amide with an acid chloride, implying an amide coupling reaction. Some non-proteinogenic amino acids may need to be synthesized separately.'] filename=rec_prithvi.py job_id=20241224_111414_17923 lineno=54
# 2024-12-24 05:46:08 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20241224_111414_17923 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2024-12-24 05:46:41 [info     ] AZ solved CC(C)CCCCCCCCC(=O)O  filename=rec_prithvi.py job_id=20241224_111414_17923 lineno=73
# 2024-12-24 05:46:41 [info     ] AZ_MODEL_CONFIG_PATH found: /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/prod/../aizynthfinder/models/config.yml filename=az.py job_id=20241224_111414_17923 lineno=35
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_model.onnx to uspto
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_templates.csv.gz to uspto
# Loading template-based expansion policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_model.onnx to ringbreaker
# Loading templates from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_ringbreaker_templates.csv.gz to ringbreaker
# Loading filter policy model from /Users/shreyasv/Desktop/research/deepchem/retrosynthesis/aizynthfinder/models/uspto_filter_model.onnx to uspto
# Loading stock from InMemoryInchiKeyQuery to zinc
# Selected as stock: zinc
# Compounds in stock: 17422831
# Selected as expansion policy: uspto
# Selected as filter policy: uspto
# 2024-12-24 05:47:39 [info     ] AZ failed for N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O, running LLM filename=rec_prithvi.py job_id=20241224_111414_17923 lineno=31
# 2024-12-24 05:47:39 [info     ] Calling LLM with molecule: N[C@@H]1[C@H]([C@@H]([C@H](O[C@H]1OC2=C3C=C4C=C2OC5=C(C=C(C=C5)[C@H]([C@H]6C(=O)N[C@@H](C7=C(C(=CC(=C7)O)O[C@@H]8[C@H]([C@H]([C@@H]([C@H](O8)CO)O)O)O)C9=C(C=CC(=C9)[C@H](C(=O)N6)NC(=O)[C@@H]4NC(=O)[C@@H]1C2=C(C(=CC(=C2)OC2=C(C=CC(=C2)[C@H](C(=O)N[C@H](CC2=CC=C(O3)C=C2)C(=O)N1)NC)O)O)Cl)O)C(=O)NCCCN(C)C)O)Cl)C(=O)O)O)O and run: 0.0 filename=llm.py job_id=20241224_111414_17923 lineno=154
# 11:17:39 - LiteLLM:INFO: utils.py:2723 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# 2024-12-24 05:48:16 [info     ] Error in calling claude-3-opus-20240229: litellm.BadRequestError: litellm.ContentPolicyViolationError: AnthropicError - {"type":"error","error":{"type":"invalid_request_error","message":"Output blocked by content filtering policy"}} filename=llm.py job_id=20241224_111414_17923 lineno=54
# 2024-12-24 05:48:16 [info     ] Retrying call to claude-3-opus-20240229 filename=llm.py job_id=20241224_111414_17923 lineno=55
# 11:18:16 - LiteLLM:INFO: utils.py:2723 -
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
#
# LiteLLM completion() model= claude-3-opus-20240229; provider = anthropic
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.

# %%
res_dict
# Out:
# {'dependencies': {'1': ['2', '10'],
#   '2': ['3', '7'],
#   '3': ['4'],
#   '4': ['5'],
#   '5': ['6'],
#   '6': [],
#   '7': ['8'],
#   '8': ['9'],
#   '9': [],
#   '10': []},
#  'steps': [{'step': '1',
#    'reactants': [{'smiles': 'O=C(NC1=CC(C(F)(F)F)=CC(N)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(N)=CC(C(F)(F)F)=C4)=O)=C3',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C28H28F6N8O4',
#       'mass': 654.2137706960002}},
#     {'smiles': 'N=C(N)NCCCCC(=O)Cl',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C6H12ClN3O',
#       'mass': 177.066889684}}],
#    'reagents': [],
#    'products': [{'smiles': 'O=C(NC1=CC(C(F)(F)F)=CC(NC(CCCCNC(N)=N)=O)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(NC(CCCCNC(N)=N)=O)=CC(C(F)(F)F)=C4)=O)=C3',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C40H50F6N14O6',
#       'mass': 936.3941946400001}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.9,
#      'closestliterature': ''}]},
#   {'step': '2',
#    'reactants': [{'smiles': 'Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCNC1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C17H16F3N5O4',
#       'mass': 411.115438652}},
#     {'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCNC1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C11H14F3N3O',
#       'mass': 261.108896728}}],
#    'reagents': [],
#    'products': [{'smiles': 'O=C(NC1=CC(C(F)(F)F)=CC(N)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(N)=CC(C(F)(F)F)=C4)=O)=C3',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C28H28F6N8O4',
#       'mass': 654.2137706960002}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.9,
#      'closestliterature': ''}]},
#   {'step': '3',
#    'reactants': [{'smiles': 'Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C19H15F6N5O5',
#       'mass': 507.0977379}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCNC1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C17H16F3N5O4',
#       'mass': 411.115438652}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '9',
#      'confidenceestimate': 0.99,
#      'closestliterature': ''}]},
#   {'step': '4',
#    'reactants': [{'smiles': 'O=C(O)c1cc(C(=O)O)ncn1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C6H4N2O4',
#       'mass': 168.017106608}},
#     {'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C13H13F6N3O2',
#       'mass': 357.091195976}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C19H15F6N5O5',
#       'mass': 507.0977379}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '9',
#      'confidenceestimate': 0.97,
#      'closestliterature': ''}]},
#   {'step': '5',
#    'reactants': [{'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C13H11F6N3O4',
#       'mass': 387.065375152}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C13H13F6N3O2',
#       'mass': 357.091195976}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.89,
#      'closestliterature': ''}]},
#   {'step': '6',
#    'reactants': [{'smiles': 'O=C(N1CC[C@@H](O)C1)C(F)(F)F',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C6H8F3NO2',
#       'mass': 183.050713156}},
#     {'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1F',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C7H4F4N2O2',
#       'mass': 224.020890248}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C13H11F6N3O4',
#       'mass': 387.065375152}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.81,
#      'closestliterature': ''}]},
#   {'step': '7',
#    'reactants': [{'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(Cc2ccccc2)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C18H20F3N3O',
#       'mass': 351.15584692}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCNC1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C11H14F3N3O',
#       'mass': 261.108896728}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.83,
#      'closestliterature': ''}]},
#   {'step': '8',
#    'reactants': [{'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(Cc2ccccc2)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C18H18F3N3O3',
#       'mass': 381.130026096}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(Cc2ccccc2)C1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C18H20F3N3O',
#       'mass': 351.15584692}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.71,
#      'closestliterature': ''}]},
#   {'step': '9',
#    'reactants': [{'smiles': 'O[C@@H]1CCN(Cc2ccccc2)C1',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C11H15NO',
#       'mass': 177.1153641}},
#     {'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1F',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C7H4F4N2O2',
#       'mass': 224.020890248}}],
#    'reagents': [],
#    'products': [{'smiles': 'Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(Cc2ccccc2)C1',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C18H18F3N3O3',
#       'mass': 381.130026096}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '8',
#      'confidenceestimate': 0.64,
#      'closestliterature': ''}]},
#   {'step': '10',
#    'reactants': [{'smiles': 'O=S(Cl)Cl',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'Cl2OS',
#       'mass': 117.90469098}},
#     {'smiles': 'N=C(N)NCCCCC(=O)O',
#      'reactant_metadata': {'name': '',
#       'chemical_formula': 'C6H13N3O2',
#       'mass': 159.100776656}}],
#    'reagents': [],
#    'products': [{'smiles': 'N=C(N)NCCCCC(=O)Cl',
#      'product_metadata': {'name': '',
#       'chemical_formula': 'C6H12ClN3O',
#       'mass': 177.066889684}}],
#    'conditions': [],
#    'reactionmetrics': [{'scalabilityindex': '9',
#      'confidenceestimate': 0.74,
#      'closestliterature': ''}]}]}

# %%
import json
with open(f"deepforestsci_mol{index+7}_path_description.json", "w") as f:
    json.dump(res_dict, f, indent=4)

# %%
import json

confidence = 0
with open(f"deepforestsci_{index+3}.{index-1}_path_alt.json", "w") as f:
    json.dump(res_dict, f, indent=4)

# %%
to_print = {}
for step in res_dict['steps']:
    temp = ""
    react_str = ""
    for react in step['reactants']:
        react_str += react['smiles'] + "."

    for reagent in step['reagents']:
        react_str += reagent['smiles'] + "."

    react_str = react_str.rstrip(".")
    temp += react_str + ">>"
    for prod in step['products']:
        temp += prod['smiles']
    to_print[step['step']] = temp

for i in to_print:
    print(f"{to_print[i]}")
# Out:
# O=C(NC1=CC(C(F)(F)F)=CC(N)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(N)=CC(C(F)(F)F)=C4)=O)=C3.N=C(N)NCCCCC(=O)Cl>>O=C(NC1=CC(C(F)(F)F)=CC(NC(CCCCNC(N)=N)=O)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(NC(CCCCNC(N)=N)=O)=CC(C(F)(F)F)=C4)=O)=C3
# Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCNC1.Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCNC1>>O=C(NC1=CC(C(F)(F)F)=CC(N)=C1O[C@@H]2CCNC2)C3=NC=NC(C(NC4=C(O[C@H]5CNCC5)C(N)=CC(C(F)(F)F)=C4)=O)=C3
# Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1>>Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCNC1
# O=C(O)c1cc(C(=O)O)ncn1.Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1>>Nc1cc(C(F)(F)F)cc(NC(=O)c2cc(C(=O)O)ncn2)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1
# Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1>>Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1
# O=C(N1CC[C@@H](O)C1)C(F)(F)F.Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1F>>Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(C(=O)C(F)(F)F)C1
# Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(Cc2ccccc2)C1>>Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCNC1
# Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(Cc2ccccc2)C1>>Nc1cc(C(F)(F)F)cc(N)c1O[C@@H]1CCN(Cc2ccccc2)C1
# O[C@@H]1CCN(Cc2ccccc2)C1.Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1F>>Nc1cc(C(F)(F)F)cc([N+](=O)[O-])c1O[C@@H]1CCN(Cc2ccccc2)C1
# O=S(Cl)Cl.N=C(N)NCCCCC(=O)O>>N=C(N)NCCCCC(=O)Cl

# %% [markdown]
# # Runs on USPTO

# %%
# load up USPTO-50k test dataset
import pandas as pd

# df = pd.read_csv("USPTO-50k/test.csv")

# now extract 500 entries from the dataset
# df = df.sample(500, random_state=42)
# df.sort_index(inplace=True)
# df.to_csv("USPTO-50k_500.csv")
df = pd.read_csv("USPTO-50k_500_failed.csv", index_col=0)
df
# Out:
#                                                   input  \
# 119   COC(=O)c1cccc(C(=O)N2CCC(CCN3C4CCC3CC(n3c(C)nc...
# 290   CC(=O)N[C@H]1CC[C@H](NC(=O)c2c(C)[nH]c3c(-c4cc...
# 346   CCC(C)N1CC(c2c(C)c(Cl)cc(C(C)n3nc(C)c4c(N)ncnc...
# 483   Cc1c(-c2ccccc2)c2c(c3c1[nH]c1ccc(O)cc13)C(=O)N...
# 1618  COc1ccc(N(C(=O)CN2C(=O)Cc3nnc(C4CCCCC4)n3-c3cc...
# ...                                                 ...
# 9703  CNc1c(F)cc2c(=O)c(C(=O)O)cn(-c3nc(NCCO)c(F)cc3...
# 9772  C[C@@H]1C(=O)C(C#N)=C[C@]2(c3cccc(C(=O)O)c3)c3...
# 9824                            NCCc1cnn2ccc3c(c12)CCO3
# 9832                    Cc1ccc(S(=O)(=O)NC2CCCNC2=O)cc1
# 9906  O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F)...
#
#                                                  output  reaction_type
# 119   COC(=O)c1cccc(C(=O)O)c1.Cc1nc2ccccc2n1C1CC2CCC...              2
# 290   CC(=O)Cl.Cc1[nH]c2c(-c3cc(C(F)F)ccc3OCC3CC3)nc...              2
# 346   CCC(C)=O.COc1c(C(C)n2nc(C)c3c(N)ncnc32)cc(Cl)c...              1
# 483   COc1ccc2[nH]c3c(C)c(-c4ccccc4)c4c(c3c2c1)C(=O)...              6
# 1618  COc1ccc(N(C(=O)CBr)C(C)C)cn1.O=C1Cc2nnc(C3CCCC...              1
# ...                                                 ...            ...
# 9703  CN.O=C(O)c1cn(-c2nc(NCCO)c(F)cc2F)c2c(Cl)c(F)c...              1
# 9772  COC(=O)c1cccc([C@]23C=C(C#N)C(=O)[C@@H](C)[C@@...              6
# 9824                           N#CCc1cnn2ccc3c(c12)CCO3              7
# 9832                 Cc1ccc(S(=O)(=O)Cl)cc1.NC1CCCNC1=O              2
# 9906  CCOC(=O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(...              6
#
# [67 rows x 3 columns]

# %%
from utils import clear_cache, run_prithvi
import json
# Out:
# 2024-10-02 17:06:23.621571: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-02 17:06:23.622014: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 17:06:23.625634: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 17:06:23.664526: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-02 17:06:24.329745: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
mols_error_fail = [119, 346, 483, 1618, 3027, 7273]

# %%
mols_rec_depth_fail = [5411, 5790, 7030, 8813, 9772]

# %%
mols_list_index_fail = [2310, 2625, 6575, 9824]

# %%
failed_mols = [
    119, 290, 346, 483, 1618, 2310, 2625, 3027, 3333, 3381, 3399, 3448, 3460,
    3464, 3481, 3495, 3497, 3532, 3548, 3767, 3771, 3815, 4313, 4411, 4661,
    4704, 5143, 5336, 5382, 5395, 5411, 5441, 5467, 5477, 5651, 5682, 5790,
    5894, 6310, 6575, 7030, 7273, 7290, 7292, 7315, 7372, 7388, 7428, 7457,
    7665, 7716, 7818, 8543, 8813, 9009, 9255, 9320, 9372, 9411, 9412, 9512,
    9534, 9703, 9772, 9824, 9832, 9906
]

# %%
df.iloc[8]
# Out:
# input            NC(=O)c1ccsc1-c1n[nH]c2c(F)c(-c3ccc(N)c(F)c3)c...
# output           CC(C)(C)OC(=O)Nc1ccc(-c2ccc3c(-c4sccc4C(N)=O)n...
# reaction_type                                                    6
# Name: 3333, dtype: object

# %%
# extract the failed molecules

# df_failed = df.loc[failed_mols]

# %%
# df_failed.to_csv("USPTO-50k_500_failed.csv")

# %%
df.head(10)
# Out:
#                                                   input  \
# 119   COC(=O)c1cccc(C(=O)N2CCC(CCN3C4CCC3CC(n3c(C)nc...
# 290   CC(=O)N[C@H]1CC[C@H](NC(=O)c2c(C)[nH]c3c(-c4cc...
# 346   CCC(C)N1CC(c2c(C)c(Cl)cc(C(C)n3nc(C)c4c(N)ncnc...
# 483   Cc1c(-c2ccccc2)c2c(c3c1[nH]c1ccc(O)cc13)C(=O)N...
# 1618  COc1ccc(N(C(=O)CN2C(=O)Cc3nnc(C4CCCCC4)n3-c3cc...
# 2310         CN1CCN(Cc2c(CO)c(Cl)nc3cc4c(cc23)OCCO4)CC1
# 2625       CCOC(=O)/C=C/c1c(O)c(=O)[nH]c2cc(Cl)ccc2c1=O
# 3027  CCC(CC)(c1ccc(OCC(O[Si](C)(C)C(C)(C)C)C(C)(C)C...
# 3333  NC(=O)c1ccsc1-c1n[nH]c2c(F)c(-c3ccc(N)c(F)c3)c...
# 3381  CCn1cc(-c2cccc(NC(=O)Nc3ccccc3Cl)c2)c(-c2ccncc...
#
#                                                  output  reaction_type
# 119   COC(=O)c1cccc(C(=O)O)c1.Cc1nc2ccccc2n1C1CC2CCC...              2
# 290   CC(=O)Cl.Cc1[nH]c2c(-c3cc(C(F)F)ccc3OCC3CC3)nc...              2
# 346   CCC(C)=O.COc1c(C(C)n2nc(C)c3c(N)ncnc32)cc(Cl)c...              1
# 483   COc1ccc2[nH]c3c(C)c(-c4ccccc4)c4c(c3c2c1)C(=O)...              6
# 1618  COc1ccc(N(C(=O)CBr)C(C)C)cn1.O=C1Cc2nnc(C3CCCC...              1
# 2310      COC(=O)c1c(Cl)nc2cc3c(cc2c1CN1CCN(C)CC1)OCCO3              7
# 2625        CCOC(=O)C=Cc1c(OC)c(=O)[nH]c2cc(Cl)ccc2c1=O              6
# 3027  CCC(CC)(c1ccc(OCC(O[Si](C)(C)C(C)(C)C)C(C)(C)C...              7
# 3333  CC(C)(C)OC(=O)Nc1ccc(-c2ccc3c(-c4sccc4C(N)=O)n...              6
# 3381  CCn1cc(-c2cccc(N)c2)c(-c2ccncc2)n1.O=C=Nc1cccc...              2

# %%
# now run prithvi on the dataset

# for i, row in df.iterrows():
#     print(f"Running {i}")
#     try:
#         res_dict = run_prithvi(row['input'])
#         with open(f"results/USPTO-50k_500/{i}.json", "w") as f:
#             json.dump(res_dict, f, indent=4)
#     except Exception as e:
#         print("Error in molecule:", i)
#         print("Error:", e)

# add tqdm to show progress
from tqdm import tqdm

for i, row in tqdm(df.iterrows(), total=len(df)):
    if i in mols_list_index_fail:
        print(f"Running {i}")
        res_dict = run_prithvi(row['input'])
        print("saving")
        try:

            with open(f"results/USPTO-50k_500/{i}.json", "w") as f:
                json.dump(res_dict, f, indent=4)
        except Exception as e:
            print("Error in molecule:", i)
            print("Error:", e)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Merging results

# %%
df = pd.read_csv("data/USPTO-50k_500.csv", index_col=0)

# %%
def get_results_in_file(file):
    step_1 = file['steps'][0]
    reactants = []
    for react in step_1['reactants']:
        reactants.append(react['smiles'])
    reagents = []
    for reagent in step_1['reagents']:
        reagents.append(reagent['smiles'])
    products = []
    for prod in step_1['products']:
        products.append(prod['smiles'])
    return reactants, reagents, products

# %%
json_file = "results/USPTO-50k_500/14.json"

with open(json_file) as f:
    res = json.load(f)

get_results_in_file(res)
# Out:
# (['NC1CNC1', 'COc1ccc(F)c(F)c1C(=O)c1cnc(Cl)nc1N'],
#  [],
#  ['COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N'])

# %%
# load up the results
import json
import os
import pandas as pd

dir_results = "results/USPTO-50k_500/"

# find files in dir_results
files = [
    f for f in os.listdir(dir_results)
    if os.path.isfile(os.path.join(dir_results, f))
]

# load up the results in a df
results = {}
for file in files:
    with open(os.path.join(dir_results, file)) as f:
        reactants, reagents, products = get_results_in_file(json.load(f))
        results[int(file.split(".")[0])] = {
            "reactants": reactants,
            "reagents": reagents,
            "products": products
        }

results_df = pd.DataFrame(results).T
# sort based on index
results_df.sort_index(inplace=True)
results_df
# Out:
#                                               reactants   reagents  \
# 3     [Cc1cc(C=O)cc2nc[nH]c12, OC(C[C@@H](OC(=O)N1CC...         []
# 14        [NC1CNC1, COc1ccc(F)c(F)c1C(=O)c1cnc(Cl)nc1N]         []
# 29                                  [COc1cccc(C=O)c1OC]  [C1CCOC1]
# 31             [CC(C)S(=O)c1nc[nH]n1, CCCN(CCC)C(=O)Cl]         []
# 33    [O=C1NC[C@H](c2ccccc2)N1, O=C(c1ccc([N+](=O)[O...         []
# ...                                                 ...        ...
# 9880  [COC(=O)CN(Cc1ccc2c(c1)OCO2)C(=O)c1ccc(-c2cccc...         []
# 9890  [ClCc1csc(N2CCCCC2)n1, COc1cc(COc2nn(-c3ccccc3...         []
# 9906  [O=C(O)CC1CCc2c1[nH]c1ccc(Br)cc21, O=C(O)CN1CC...         []
# 9937       [COC(=O)OC, O=C1CCCOc2ccc(-c3ccc(F)cc3)cc21]         []
# 9948  [CC(C)C(=O)Nc1ccccc1, Cc1ccc(OCCCCN2CC=CCC2)cc1C]         []
#
#                                                products
# 3     [Cc1cc(C[C@@H](OC(=O)N2CCC(N3CCc4ccccc4NC3=O)C...
# 14            [COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N]
# 29                                [COC=Cc1cccc(OC)c1OC]
# 31                  [CCCN(CCC)C(=O)n1cnc(S(=O)C(C)C)n1]
# 33    [O=C(c1ccc([N+](=O)[O-])cc1)N1CCc2cc(S(=O)(=O)...
# ...                                                 ...
# 9880  [COC(=O)c1c(-c2ccccc2)c2cc(-c3ccccc3)ccc2c(=O)...
# 9890  [COc1cc(COc2nn(-c3ccccc3)cc2C=O)ccc1OCc1csc(N2...
# 9906  [O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F...
# 9937             [O=C(O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1]
# 9948  [Cc1ccc(OCCCCN2CCC(c3cccc(NC(=O)C(C)C)c3)CC2)c...
#
# [481 rows x 3 columns]

# %%
# map results to the original dataset based on the index
df_results = df.join(results_df, on=df.index)
# Out:
#                                                     input  \
# mol_no
# 3       Cc1cc(C[C@@H](OC(=O)N2CCC(N3CCc4ccccc4NC3=O)CC...
# 14                COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N
# 29                                    COC=Cc1cccc(OC)c1OC
# 31                      CCCN(CCC)C(=O)n1cnc(S(=O)C(C)C)n1
# 33      O=C(c1ccc([N+](=O)[O-])cc1)N1CCc2cc(S(=O)(=O)N...
# ...                                                   ...
# 9880    COC(=O)c1c(-c2ccccc2)c2cc(-c3ccccc3)ccc2c(=O)n...
# 9890    COc1cc(COc2nn(-c3ccccc3)cc2C=O)ccc1OCc1csc(N2C...
# 9906    O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F)...
# 9937                 O=C(O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1
# 9948     Cc1ccc(OCCCCN2CCC(c3cccc(NC(=O)C(C)C)c3)CC2)cc1C
#
#                                                    output  reaction_type  \
# mol_no
# 3       CS(=O)(=O)N1CCC(C2CCNCC2)CC1.Cc1cc(C[C@@H](OC(...              2
# 14      COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CN(C(=O)OC(C)(C)...              6
# 29      COC[P+](c1ccccc1)(c1ccccc1)c1ccccc1.COc1cccc(C...              3
# 31                  CC(C)S(=O)c1nc[nH]n1.CCCN(CCC)C(=O)Cl              1
# 33      O=C(Cl)c1ccc([N+](=O)[O-])cc1.O=C1N[C@@H](c2cc...              2
# ...                                                   ...            ...
# 9880    COC(=O)c1c(-c2ccccc2)c2cc(Br)ccc2c(=O)n1Cc1ccc...              3
# 9890    COc1cc(CO)ccc1OCc1csc(N2CCCCC2)n1.O=Cc1cn(-c2c...              1
# 9906    CCOC(=O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(...              6
# 9937                COC(=O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1              6
# 9948    CC(C)C(=O)Nc1cccc(C2CCNCC2)c1.Cc1ccc(OCCCCCl)cc1C              1
#
#                                                 reactants   reagents  \
# mol_no
# 3       [Cc1cc(C=O)cc2nc[nH]c12, OC(C[C@@H](OC(=O)N1CC...         []
# 14          [NC1CNC1, COc1ccc(F)c(F)c1C(=O)c1cnc(Cl)nc1N]         []
# 29                                    [COc1cccc(C=O)c1OC]  [C1CCOC1]
# 31               [CC(C)S(=O)c1nc[nH]n1, CCCN(CCC)C(=O)Cl]         []
# 33      [O=C1NC[C@H](c2ccccc2)N1, O=C(c1ccc([N+](=O)[O...         []
# ...                                                   ...        ...
# 9880    [COC(=O)CN(Cc1ccc2c(c1)OCO2)C(=O)c1ccc(-c2cccc...         []
# 9890    [ClCc1csc(N2CCCCC2)n1, COc1cc(COc2nn(-c3ccccc3...         []
# 9906    [O=C(O)CC1CCc2c1[nH]c1ccc(Br)cc21, O=C(O)CN1CC...         []
# 9937         [COC(=O)OC, O=C1CCCOc2ccc(-c3ccc(F)cc3)cc21]         []
# 9948    [CC(C)C(=O)Nc1ccccc1, Cc1ccc(OCCCCN2CC=CCC2)cc1C]         []
#
#                                                  products
# mol_no
# 3       [Cc1cc(C[C@@H](OC(=O)N2CCC(N3CCc4ccccc4NC3=O)C...
# 14              [COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N]
# 29                                  [COC=Cc1cccc(OC)c1OC]
# 31                    [CCCN(CCC)C(=O)n1cnc(S(=O)C(C)C)n1]
# 33      [O=C(c1ccc([N+](=O)[O-])cc1)N1CCc2cc(S(=O)(=O)...
# ...                                                   ...
# 9880    [COC(=O)c1c(-c2ccccc2)c2cc(-c3ccccc3)ccc2c(=O)...
# 9890    [COc1cc(COc2nn(-c3ccccc3)cc2C=O)ccc1OCc1csc(N2...
# 9906    [O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F...
# 9937               [O=C(O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1]
# 9948    [Cc1ccc(OCCCCN2CCC(c3cccc(NC(=O)C(C)C)c3)CC2)c...
#
# [500 rows x 6 columns]

# %% [markdown]
# ### Final Evaluation

# %%
import ast
import pandas as pd

df_results = pd.read_csv("data/USPTO-50k_500_results.csv", index_col=0)
# drop nan values
df_results.dropna(inplace=True)

# convert the smiles to a list
df_results['reactants'] = df_results['reactants'].apply(
    lambda x: ast.literal_eval(x))
df_results['reagents'] = df_results['reagents'].apply(
    lambda x: ast.literal_eval(x))
df_results['products'] = df_results['products'].apply(
    lambda x: ast.literal_eval(x))
df_results
# Out:
#                                                   input  \
# 3     Cc1cc(C[C@@H](OC(=O)N2CCC(N3CCc4ccccc4NC3=O)CC...
# 14              COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N
# 29                                  COC=Cc1cccc(OC)c1OC
# 31                    CCCN(CCC)C(=O)n1cnc(S(=O)C(C)C)n1
# 33    O=C(c1ccc([N+](=O)[O-])cc1)N1CCc2cc(S(=O)(=O)N...
# ...                                                 ...
# 9880  COC(=O)c1c(-c2ccccc2)c2cc(-c3ccccc3)ccc2c(=O)n...
# 9890  COc1cc(COc2nn(-c3ccccc3)cc2C=O)ccc1OCc1csc(N2C...
# 9906  O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F)...
# 9937               O=C(O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1
# 9948   Cc1ccc(OCCCCN2CCC(c3cccc(NC(=O)C(C)C)c3)CC2)cc1C
#
#                                                  output  reaction_type  \
# 3     CS(=O)(=O)N1CCC(C2CCNCC2)CC1.Cc1cc(C[C@@H](OC(...              2
# 14    COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CN(C(=O)OC(C)(C)...              6
# 29    COC[P+](c1ccccc1)(c1ccccc1)c1ccccc1.COc1cccc(C...              3
# 31                CC(C)S(=O)c1nc[nH]n1.CCCN(CCC)C(=O)Cl              1
# 33    O=C(Cl)c1ccc([N+](=O)[O-])cc1.O=C1N[C@@H](c2cc...              2
# ...                                                 ...            ...
# 9880  COC(=O)c1c(-c2ccccc2)c2cc(Br)ccc2c(=O)n1Cc1ccc...              3
# 9890  COc1cc(CO)ccc1OCc1csc(N2CCCCC2)n1.O=Cc1cn(-c2c...              1
# 9906  CCOC(=O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(...              6
# 9937              COC(=O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1              6
# 9948  CC(C)C(=O)Nc1cccc(C2CCNCC2)c1.Cc1ccc(OCCCCCl)cc1C              1
#
#                                               reactants   reagents  \
# 3     [Cc1cc(C=O)cc2nc[nH]c12, OC(C[C@@H](OC(=O)N1CC...         []
# 14        [NC1CNC1, COc1ccc(F)c(F)c1C(=O)c1cnc(Cl)nc1N]         []
# 29                                  [COc1cccc(C=O)c1OC]  [C1CCOC1]
# 31             [CC(C)S(=O)c1nc[nH]n1, CCCN(CCC)C(=O)Cl]         []
# 33    [O=C1NC[C@H](c2ccccc2)N1, O=C(c1ccc([N+](=O)[O...         []
# ...                                                 ...        ...
# 9880  [COC(=O)CN(Cc1ccc2c(c1)OCO2)C(=O)c1ccc(-c2cccc...         []
# 9890  [ClCc1csc(N2CCCCC2)n1, COc1cc(COc2nn(-c3ccccc3...         []
# 9906  [O=C(O)CC1CCc2c1[nH]c1ccc(Br)cc21, O=C(O)CN1CC...         []
# 9937       [COC(=O)OC, O=C1CCCOc2ccc(-c3ccc(F)cc3)cc21]         []
# 9948  [CC(C)C(=O)Nc1ccccc1, Cc1ccc(OCCCCN2CC=CCC2)cc1C]         []
#
#                                                products
# 3     [Cc1cc(C[C@@H](OC(=O)N2CCC(N3CCc4ccccc4NC3=O)C...
# 14            [COc1ccc(F)c(F)c1C(=O)c1cnc(NC2CNC2)nc1N]
# 29                                [COC=Cc1cccc(OC)c1OC]
# 31                  [CCCN(CCC)C(=O)n1cnc(S(=O)C(C)C)n1]
# 33    [O=C(c1ccc([N+](=O)[O-])cc1)N1CCc2cc(S(=O)(=O)...
# ...                                                 ...
# 9880  [COC(=O)c1c(-c2ccccc2)c2cc(-c3ccccc3)ccc2c(=O)...
# 9890  [COc1cc(COc2nn(-c3ccccc3)cc2C=O)ccc1OCc1csc(N2...
# 9906  [O=C(O)CC1CCc2c1[nH]c1ccc(-c3noc(-c4cc(OC(F)(F...
# 9937             [O=C(O)C1=Cc2cc(-c3ccc(F)cc3)ccc2OCC1]
# 9948  [Cc1ccc(OCCCCN2CCC(c3cccc(NC(=O)C(C)C)c3)CC2)c...
#
# [481 rows x 6 columns]

# %%
# Check if the input is the same as the first product
for i, row in df_results.iterrows():
    # print(row)
    try:
        if row['input'] != row['products'][0]:
            print(i)
            # print(i)
    except Exception as e:
        print(i)
        print(row['products'])
        print(e)

# %%
# actual evaluation
from rdkit import Chem

not_common = []
missed = []

for i, row in df_results.iterrows():
    outputs = row['output'].split('.')
    predicted_outputs = row['reactants'] + row['reagents']
    outputs_mols = [Chem.CanonSmiles(output) for output in outputs]
    predicted_outputs_mols = [
        Chem.CanonSmiles(output) for output in predicted_outputs
    ]
    # print(outputs_mols)
    # print(predicted_outputs_mols)
    # break
    # check if all the predicted outputs are in the actual outputs
    if any([output in outputs_mols for output in predicted_outputs_mols
            ]) and len(outputs_mols) == len(predicted_outputs_mols):
        df_results.loc[i, 'any_correct'] = 1
    else:
        df_results.loc[i, 'any_correct'] = 0

    if all([output in outputs_mols for output in predicted_outputs_mols
            ]) and len(outputs_mols) == len(predicted_outputs_mols):
        df_results.loc[i, 'all_correct'] = 1
    else:
        df_results.loc[i, 'all_correct'] = 0
    # get the molecules that are not common
    not_common.append([
        output for output in predicted_outputs_mols
        if output not in outputs_mols
    ])
    # df_results.loc[i, 'not_common'] =
    # get the molecules that are missed
    missed.append([
        output for output in outputs_mols
        if output not in predicted_outputs_mols
    ])

df_results['not_common'] = not_common
df_results['missed'] = missed

# %%
print("All correct %", 100 * df_results.all_correct.sum() / len(df_results))
print("Any correct %", 100 * df_results.any_correct.sum() / len(df_results))
# Out:
# All correct % 25.363825363825363
# Any correct % 34.51143451143451

# %%
# print rows where df_results['any_correct'] != 1
df_results[df_results['any_correct'] != 1].to_csv(
    "data/USPTO-50k_500_manual_verification.csv")
